# %%
#importing libraries
import pandas as pd
import numpy as np

import json, time, urllib.parse
import requests

# %% [markdown]
# ## Step 1: Getting the Article and Population Data

# %% [markdown]
# We read the excel files stored in the data_raw folder, these correspond to Wikipedias polititians by country and  Population Reference Bureau's world population by country datasets.

# %%
politicians = pd.read_excel('../data_raw/politicians_by_country_SEPT.2022.csv.xlsx')
population = pd.read_excel('../data_raw/population_by_country_2022.csv.xlsx')

# %% [markdown]
# ## Handling data inconsistencies
# We do some data exploration and examination to find if there are any inconsistencies, if so, we will specify how we decided to handle each

# %%
politicians[politicians.duplicated(subset=['name'])]
# Out:
#                                            name  \
# 1566                                 Rudi Kolak
# 1654  Count Wenzel Chotek of Chotkow and Wognin
# 1669                            Eduard Hedvicek
# 1676                         Konstantin Jireček
# 1680              Maximilian Ulrich von Kaunitz
# 1711     Leopold, Count von Thun und Hohenstein
# 1914                              Ibrahim Harun
# 2513                 José Alejandro de Aycinena
# 2659                   José Francisco Barrundia
# 3419                             Luca Rovinalti
# 3874                               Bak Jungyang
# 3893                                Kim Gap-sun
# 3965                                Visar Ymeri
# 3983                        Torokul Dzhanuzakov
# 4785                               P. F. Dahler
# 5148                          Ashab Uddin Ahmad
# 5158                  Moinuddin Ahmed Chowdhury
# 5159                      Zahur Ahmad Chowdhury
# 5253                             Mohammad Toaha
# 5460                         Heinrich von Brühl
# 5724                           Ali al-Qaradaghi
# 5817                           German Kuznetsov
# 5944                              Karamba Diaby
# 5974                             Shqiprim Arifi
# 5980                             Melko Čingrija
# 6001                            Oliver Ivanović
# 6015                     Stjepan Mitrov Ljubiša
# 6025                         Vladimir Pavićević
# 6027                        Svetozar Pribićević
# 6034                                Goran Rakić
# 6052                            Lazar Tomanović
# 6113                           Antonín Janoušek
# 6115                                Juraj Košút
# 6139                             Josip Ferfolja
# 6146                               Jožef Krajnc
# 6209                           Djama Ali Moussa
# 6295                   Abdirahman Aw Ali Farrah
# 6309                      Ibrahim Megag Samatar
# 6527                  Antonio Gutiérrez y Ulloa
# 6598                            Manuel Marliani
# 6608                             Rafael Montoro
# 6720                    Grace Schneiders-Howard
# 6729                           Alexandra Benado
# 6776                 Jacob Magnus Sprengtporten
# 6877                              Hrant Maloyan
# 6894                        Torokul Dzhanuzakov
# 6962                                 Yat Hwaidi
# 6964                         Manuel Carrascalão
# 7187                              Sergey Abisov
# 7341                        Torokul Dzhanuzakov
#
#                                                     url      country
# 1566           https://en.wikipedia.org/wiki/Rudi_Kolak      Croatia
# 1654  https://en.wikipedia.org/wiki/Count_Wenzel_Cho...      Czechia
# 1669      https://en.wikipedia.org/wiki/Eduard_Hedvicek      Czechia
# 1676   https://en.wikipedia.org/wiki/Konstantin_Jireček      Czechia
# 1680  https://en.wikipedia.org/wiki/Maximilian_Ulric...      Czechia
# 1711  https://en.wikipedia.org/wiki/Leopold,_Count_v...      Czechia
# 1914        https://en.wikipedia.org/wiki/Ibrahim_Harun     Ethiopia
# 2513  https://en.wikipedia.org/wiki/José_Alejandro_d...    Guatemala
# 2659  https://en.wikipedia.org/wiki/José_Francisco_B...     Honduras
# 3419       https://en.wikipedia.org/wiki/Luca_Rovinalti        Italy
# 3874         https://en.wikipedia.org/wiki/Bak_Jungyang       Korean
# 3893          https://en.wikipedia.org/wiki/Kim_Gap-sun       Korean
# 3965          https://en.wikipedia.org/wiki/Visar_Ymeri       Kosovo
# 3983  https://en.wikipedia.org/wiki/Torokul_Dzhanuzakov   Kyrgyzstan
# 4785         https://en.wikipedia.org/wiki/P._F._Dahler  Netherlands
# 5148    https://en.wikipedia.org/wiki/Ashab_Uddin_Ahmad     Pakistan
# 5158  https://en.wikipedia.org/wiki/Moinuddin_Ahmed_...     Pakistan
# 5159  https://en.wikipedia.org/wiki/Zahur_Ahmad_Chow...     Pakistan
# 5253       https://en.wikipedia.org/wiki/Mohammad_Toaha     Pakistan
# 5460   https://en.wikipedia.org/wiki/Heinrich_von_Brühl       Poland
# 5724     https://en.wikipedia.org/wiki/Ali_al-Qaradaghi        Qatar
# 5817     https://en.wikipedia.org/wiki/German_Kuznetsov       Russia
# 5944        https://en.wikipedia.org/wiki/Karamba_Diaby      Senegal
# 5974       https://en.wikipedia.org/wiki/Shqiprim_Arifi       Serbia
# 5980       https://en.wikipedia.org/wiki/Melko_Čingrija       Serbia
# 6001      https://en.wikipedia.org/wiki/Oliver_Ivanović       Serbia
# 6015  https://en.wikipedia.org/wiki/Stjepan_Mitrov_L...       Serbia
# 6025   https://en.wikipedia.org/wiki/Vladimir_Pavićević       Serbia
# 6027  https://en.wikipedia.org/wiki/Svetozar_Pribićević       Serbia
# 6034          https://en.wikipedia.org/wiki/Goran_Rakić       Serbia
# 6052      https://en.wikipedia.org/wiki/Lazar_Tomanović       Serbia
# 6113     https://en.wikipedia.org/wiki/Antonín_Janoušek     Slovakia
# 6115          https://en.wikipedia.org/wiki/Juraj_Košút     Slovakia
# 6139       https://en.wikipedia.org/wiki/Josip_Ferfolja     Slovenia
# 6146         https://en.wikipedia.org/wiki/Jožef_Krajnc     Slovenia
# 6209     https://en.wikipedia.org/wiki/Djama_Ali_Moussa      Somalia
# 6295  https://en.wikipedia.org/wiki/Abdirahman_Aw_Al...      Somalia
# 6309  https://en.wikipedia.org/wiki/Ibrahim_Megag_Sa...      Somalia
# 6527  https://en.wikipedia.org/wiki/Antonio_Gutiérre...        Spain
# 6598      https://en.wikipedia.org/wiki/Manuel_Marliani        Spain
# 6608       https://en.wikipedia.org/wiki/Rafael_Montoro        Spain
# 6720  https://en.wikipedia.org/wiki/Grace_Schneiders...     Suriname
# 6729     https://en.wikipedia.org/wiki/Alexandra_Benado       Sweden
# 6776  https://en.wikipedia.org/wiki/Jacob_Magnus_Spr...       Sweden
# 6877        https://en.wikipedia.org/wiki/Hrant_Maloyan        Syria
# 6894  https://en.wikipedia.org/wiki/Torokul_Dzhanuzakov   Tajikistan
# 6962           https://en.wikipedia.org/wiki/Yat_Hwaidi     Thailand
# 6964   https://en.wikipedia.org/wiki/Manuel_Carrascalão  Timor-Leste
# 7187        https://en.wikipedia.org/wiki/Sergey_Abisov      Ukraine
# 7341  https://en.wikipedia.org/wiki/Torokul_Dzhanuzakov   Uzbekistan

# %% [markdown]
# We observe that aggregations are all in CAPS, we keep them as they will come in handy later in the analysis.
#
# Lastly, we notice that there are 50 duplicated politicians in our datasource. Checking in a case-by-case article basis, we note that these people have been politicians in each of the countries. This means that the data isn't corrupted, it's just an edge case. Considering that:
#
# 1. It doesn't seem logical to assign these politicians to only one country given that they have participated in politics on each of these countries.
# 2. These duplicates represent only (100/7584=0.013) 1.3% of the data.
# 3. These are politicians that have participated in politics in both of the countries so it makes sense to have them in each country.
#
# We decide to allow these duplicates to exist, but we further check if there are any duplicates for all the columns.

# %%
politicians[politicians.duplicated()]
#politicians = politicians.drop_duplicates(subset=['name'], keep=False)
# Out:
#                           name  \
# 6295  Abdirahman Aw Ali Farrah
# 6309     Ibrahim Megag Samatar
#
#                                                     url  country
# 6295  https://en.wikipedia.org/wiki/Abdirahman_Aw_Al...  Somalia
# 6309  https://en.wikipedia.org/wiki/Ibrahim_Megag_Sa...  Somalia

# %% [markdown]
# We find that there are two politicians that have duplicate rows for all columns, these are not justifiable and will be removed from the data

# %%
politicians = politicians.drop_duplicates()

# %% [markdown]
# # Step 2: Getting Article Quality Predictions

# %% [markdown]
# We begin by making a page info request to get the current page revision. The example relies on some constants that help make the code a bit more readable.

# %% [markdown]
# Basic English Wikipedia API endpoint

# %%
#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<uwnetid@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2022',
}

# This is just a list of English Wikipedia article titles that we can use for example requests
ARTICLE_TITLES = politicians.name.tolist()

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %% [markdown]
# The API request will be made using one procedure. The idea is to make this reusable. The procedure is parameterized, but relies on the constants above for the important parameters. The underlying assumption is that this will be used to request data for a set of article pages. Therefore the parameter most likely to change is the article_title.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageinfo_per_article(article_title = None, 
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT, 
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):
    # Make sure we have an article title
    if not article_title: return None
    
    request_template['titles'] = article_title
        
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# We send a request per article and store the data obtained in a dictionary called ARTICLE_REVISIONS. Any article that does not have a revision or incurred in an error is stores in the list ARTICLE_REVISIONS_NULL

# %%
ARTICLE_REVISIONS = {}
ARTICLE_REVISIONS_NULL =[]
for article in ARTICLE_TITLES:
    info = request_pageinfo_per_article(article)
    if info['query']['pages'][list(info['query']['pages'].keys())[0]].get('lastrevid','null') != 'null':
        last_rev_id = info['query']['pages'][list(info['query']['pages'].keys())[0]]['lastrevid']
        ARTICLE_REVISIONS[article] = last_rev_id
    else:
        ARTICLE_REVISIONS_NULL.append(article)

# %% [markdown]
# The following articles will have to be removed from the analysis given to their lack of information

# %%
ARTICLE_REVISIONS_NULL
# Out:
# ['Prince Ofosu Sefah',
#  'Harjit Kaur Talwandi',
#  'Abd al-Razzaq al-Hasani',
#  'Kang Sun-nam',
#  'Segun “Aeroland” Adewale',
#  'Nhlanhla “Lux” Dlamini']

# %%
ARTICLE_REVISIONS
# Out:
# {'Shahjahan Noori': 1099689043,
#  'Abdul Ghafar Lakanwal': 943562276,
#  'Majah Ha Adrif': 852404094,
#  'Haroon al-Afghani': 1095102390,
#  'Tayyab Agha': 1104998382,
#  'Ahmadullah Wasiq': 1109361754,
#  'Aziza Ahmadyar': 1087211008,
#  'Muqadasa Ahmadzai': 1082489593,
#  'Mohammad Sarwar Ahmedzai': 1038918070,
#  'Amir Muhammad Akhundzada': 1069322182,
#  'Nasrullah Baryalai Arsalai': 1095526840,
#  'Mohammad Asim Asim': 1013838830,
#  'Atiqullah Atifmal': 1112407669,
#  'Abdul Rahim Ayoubi': 1108886061,
#  'Alhaj Mutalib Baig': 1111494041,
#  'Ismael Balkhi': 1112534409,
#  'Abdul Baqi Turkistani': 889226470,
#  'Mohammad Ghous Bashiri': 1102150221,
#  'Abas Basir': 1098419766,
#  'Jan Baz': 997027082,
#  'Ahmad Behzad': 1103948295,
#  'Bashir Ahmad Bezan': 1060707209,
#  'Rafiullah Bidar': 977208323,
#  'Mohammad Siddiq Chakari': 1105913099,
#  'Cheragh Ali Cheragh': 1087211968,
#  'Nasir Ahmad Durrani': 988838315,
#  'Elay Ershad': 1102489654,
#  'Muhammad Hashim Esmatullahi': 949986748,
#  'Ezatullah (Nangarhar)': 947885788,
#  'Aimal Faizi': 1033383351,
#  'Mohammad Nasim Faqiri': 1098051193,
#  'Mohammad Nazar Faqiri': 1095525798,
#  'Sharif Ghalib': 1041460606,
#  'Hashmat Ghani Ahmadzai': 1112933356,
#  'Abdul Ghani Ghani': 1072441893,
#  'Ashraf Ghani': 1113195582,
#  'Abdul Samad Ghaus': 1072271854,
#  'Ghulam Ghaus': 1109361872,
#  'Ghulam Muhammad Ghobar': 1108886395,
#  'Mohammad Gul (Helmand Council)': 1092523687,
#  'Ghulam Haider Hamidi': 1095018556,
#  'Rangina Hamidi': 1104280812,
#  'Abdul Malik Hamwar': 1100874645,
#  'Sayed Zafar Hashemi': 1112804808,
#  'Qutbuddin Hilal': 1104423275,
#  'Shahnaz Himmeti': 909966254,
#  'Anarkali Kaur Honaryar': 1069574154,
#  'Mahboba Hoqomal': 1092518990,
#  'Musa Hotak': 1094201417,
#  'Mirza Muhammad Ismail': 1073524466,
#  'Sayed Jalal': 1078580238,
#  'Said Tayeb Jawad': 1093621927,
#  'Faizullah Kakar': 1108932917,
#  'Amin Karim': 1106333491,
#  'Sayed Jalal Karim': 1060701067,
#  'Ahmed Wali Karzai': 1090245979,
#  'Khadija Zahra Ahmadi': 1115331693,
#  'Hafizullah Shabaz Khail': 1092416288,
#  'Rouh Gul Khairzad': 925562571,
#  'Masoud Khalili': 1103105365,
#  'Mohammad Khan (athlete)': 1070779097,
#  'Samoud Khan': 1010948755,
#  'Farzana Kochai': 1079430136,
#  'Farida Kuchi': 1109436134,
#  'Baran Khan Kudezai': 1106151353,
#  'Azizullah Lodin': 1102817004,
#  'Razaq Mamoon': 1100189662,
#  'Fazel Ahmed Manawi': 1106464575,
#  'Moeen Marastial': 1102907176,
#  'Ahmad Massoud': 1112608262,
#  'Ahmad Wali Massoud': 1108236868,
#  'Mohammad Daud Miraki': 1112192884,
#  'Abdul Sattar Mirzakwal': 1044450376,
#  'Abdul Karim Misaq': 1052669338,
#  'Ali Mohammad (politician)': 1050463798,
#  'Nasruddin Mohseni': 1095044526,
#  'Davood Moradian': 1106284627,
#  'Zalmai Mujadidi': 1104635001,
#  'Fazal Haq Mujahid': 1113267490,
#  'Rahmatullah Nabil': 1112496538,
#  'Sardar Mohammad Nadir Naeem': 1038680015,
#  'Daoud Naji': 1110983467,
#  'Gholam Rabani Nasher': 916899472,
#  'Muhammad Yunus Nawandish': 1111494390,
#  'Ali Maisam Nazary': 1107279930,
#  'Ghulam Faroq Nijrabi': 1093612575,
#  'Zabih-U-llah Ghazi Noristani': 1001786762,
#  'Mohammed Tahir Omar': 996093541,
#  'Nasrin Oryakhil': 1097277701,
#  'Murad Quenili': 1093963498,
#  'Ghulam Mohammad Rigi': 918256992,
#  'Ghulam Hassan Safi': 987269301,
#  'Hanifa Safi': 994195074,
#  'Amrullah Saleh': 1115022704,
#  'Mohammed Zia Salehi': 889806024,
#  'Abdul Majid Samim': 1098092701,
#  'Saber Sangar': 1019860497,
#  'Muhammad Arif Sarwari': 1079170926,
#  'Sayed Nasim Mihanparast': 1115496635,
#  'Sayyid Husayn': 1095559301,
#  'Suhail Shaheen': 1102910228,
#  'Mohammad Shakir Kargar': 1096574840,
#  'Baktash Siawash': 1111917754,
#  'Awtar Singh': 1115100619,
#  'Hasan Ali Sultani': 1060706902,
#  'Faramarz Tamanna': 1106885861,
#  'Mohammad Hashem Taufiqui': 1021308429,
#  'Nur ul-Haq Ulumi': 1107429109,
#  'Pacha Gul Wafadar': 1020846299,
#  'Wahidullah Waissi': 1111508295,
#  'Gul Ahmmad Yama': 1060707715,
#  'Al-Haj Suliman Yari': 1092426408,
#  'Abdul Salam Zaeef': 1106388504,
#  'Abdul Zahir (Konar Education Minister)': 1097261199,
#  'Mohammed Zaman': 1108389318,
#  'Ziauddin (Afghan militia leader)': 1095799892,
#  'Qari Ziauddin': 1033608758,
#  'Abdul Ghafor Zori': 994023417,
#  'Ali Pasha of Gusinje': 1114426634,
#  'Ylli Asllani': 949182924,
#  'Azis Tahir Ajdonati': 994501003,
#  'Bislim Bajgora': 1091800566,
#  'Kastriot Berissa': 1094050369,
#  'Bardhok Biba': 1110580984,
#  'Dervish Biçaku': 1106794267,
#  'Kostandin Boshnjaku': 1107876476,
#  'Spartak Braho': 1098235893,
#  'Safet Butka': 1067080697,
#  'Uran Butka': 1087272778,
#  'Refo Çapari': 1061419179,
#  'Neritan Ceka': 1095178618,
#  'Hysni Curri': 1114418989,
#  'Ibrahim Dalliu': 1087026828,
#  'Niazi Demi': 1104589367,
#  'Abdurrahman Dibra': 1101365003,
#  'Fuad Dibra': 1079550815,
#  'Isuf Dibra': 1108975040,
#  'Bujar Dida': 1112281152,
#  'Ahmed Dino': 1114424802,
#  'Rasih Dino': 1067061654,
#  'Ferhat Bey Draga': 1101927317,
#  'Nexhip Draga': 1092914547,
#  'Aqif Pasha Elbasani': 1114425909,
#  'Abas Ermenji': 1073827690,
#  'Bajram Fevziu': 1089008480,
#  'Qamil Musa Haxhi Feza': 1015553118,
#  'Themistokli Gërmenji': 1099714241,
#  'Sabri Godo': 1105835401,
#  'Mihal Grameno': 1095879069,
#  'Aćif Hadžiahmetović': 1104696112,
#  'Albulena Haxhiu': 1095286065,
#  'High Council of Regency': 1107096289,
#  'Spiridon Kacarosi': 993288548,
#  'Kurt Agë Kadiu': 998414015,
#  'Mehmed Kalakula': 979382854,
#  'Alfred Karamuço': 1098236555,
#  'Ibrahim Karbunara': 1053849574,
#  'Ali Këlcyra': 1069956844,
#  'Belind Këlliçi': 1114971095,
#  'Bajram Kelmendi': 1098232331,
#  'Kristo Kirka': 1071577370,
#  'Elez Koçi': 919356105,
#  'Ali Riza Kolonja': 1095185542,
#  'Glauk Konjufca': 1110511667,
#  'Xhelal Koprëncka': 1106794268,
#  'Kryeziu family': 1113466121,
#  'Artur Kuko': 1112281132,
#  'Xhavid Leskoviku': 1080104315,
#  'Sabit Lulo': 1071576324,
#  'Gjon Markagjoni': 1114419158,
#  'Tefik Mborja': 1112281218,
#  'Fatmir Mediu': 1108640753,
#  'Hysni Milloshi': 1111101481,
#  'Musa Qazimi': 1085455681,
#  'Mustafa Ndroqi': 1091483288,
#  'Behxhet Nepravishta': 1114419169,
#  'Adrian Neritani': 1112281129,
#  'Sali Nivica': 1074384873,
#  'Thoma Orologa': 1114419178,
#  'Bedri Pejani': 1080373501,
#  'Pertef Pogoni': 1071576384,
#  'Kadri Prishtina': 1115424613,
#  'Ymer Prizreni': 1114419180,
#  'Avni Rustemi': 1113688253,
#  'Chatin Sarachi': 1089622596,
#  'Nebi Sefa': 978173646,
#  'Eduard Shalsi': 1090651886,
#  'Ylli Vesel Shehu': 1002857261,
#  'Athanas Shundi': 1090001664,
#  'Xhelal Sveçla': 1110419834,
#  'Mehmet Tahsini': 1089358942,
#  'Ibrahim Temo': 1114899959,
#  'Pavli Terka': 1107079359,
#  'Afrim Tole': 1091240960,
#  'Sejfi Vllamasi': 1073823015,
#  'Syrja Vlora': 1109383587,
#  'Visarion Xhuvani': 1115321286,
#  'Visar Ymeri': 1036757024,
#  'Abdyl Ypi': 1075914314,
#  'Xhezair Zaganjori': 1106753028,
#  'Menduh Zavalani': 1071577719,
#  'Said Abadou': 1112193748,
#  'Tahar Allan': 1059626268,
#  'Mohamed Seghir Babes': 1079379844,
#  'Djelloul Baghli': 1053461392,
#  'Noureddine Bahbouh': 1099284595,
#  'Lamine Bechichi': 1111537825,
#  'Bakhti Belaïb': 1107713309,
#  'Mohamed Belouizdad': 1102331624,
#  'Mourad Benachenou': 1091746754,
#  'Benaouda Hadj Hacène Bachterzi': 1064464792,
#  'Souad Bendjaballah': 1064463751,
#  'Mohammed Saleh Bendjelloul': 1064459314,
#  'Mohamed Bensalam': 1053464158,
#  'Said Boualam': 1104123484,
#  'Abdeslam Bouchouareb': 1053459025,
#  'Brahim Chibout': 1053460621,
#  'Bouras Djamel': 1072064909,
#  'Ahmed Djebbar': 1112131049,
#  'Fatiha Serour': 1019766063,
#  'Mohamed Hassaïne': 1098798192,
#  'Ibrahim Boughali': 1110540602,
#  'Abdenour Keramane': 1028900906,
#  'Abelkader Khamri': 1088927932,
#  'Mahmoud Khedri': 1102198843,
#  'Mohamed Laïchoubi': 1053469601,
#  'Sassi Lamouri': 1053478920,
#  'Mohamed Maghlaoui': 1053469610,
#  'Amar Makhloufi': 1053459748,
#  'Hacen Mefti': 1053461924,
#  'Mokhtar Meherzi': 1028900891,
#  'Mohamed Elias Mesli': 1009461580,
#  'Azzedine Mihoubi': 1031600815,
#  'Cherif Rahmani': 1053461144,
#  'Naima Salhi': 1113203380,
#  "Guillem d'Areny-Plandolit": 1100710928,
#  'Guillem Areny': 1101200095,
#  'Joan Armengol': 1105550472,
#  'Francesc Badia Batalla': 1102180575,
#  'Josep Maria Beal': 1104772844,
#  'Climent Palmitjavila': 1102731108,
#  'Antoni Puigdellívol': 1100253414,
#  'Òscar Ribas Reig': 1105529195,
#  'Boris Skossyreff': 1114575861,
#  'Enric Tarrado Vives': 986671433,
#  'Alexandre Sebastião André': 979043156,
#  'Isaac Maria dos Anjos': 1087791055,
#  'Paulino Baptista': 1098277989,
#  'João Baptista Borges': 1108136082,
#  'Branca Manuel Espirito Santo': 1082903108,
#  'André Luís Brandão': 1092527809,
#  'André Gaspar Mendes de Carvalho': 871672690,
#  'Carolina Cerqueira': 1081277226,
#  'Arlete Chimbinda': 1101656146,
#  'Kafundanga Chingunji': 1111470901,
#  'Jeremias Chitunda': 1076646666,
#  'Abel Chivukuvuku': 987997249,
#  'Adalberto Costa Júnior': 1107102259,
#  'Adjany Costa': 1081302172,
#  'Álvaro Arnaldo Craveiro': 1112653739,
#  'Raul Danda': 1099408586,
#  'Carlos António Fernandes': 1003396569,
#  'Fiel Domingos Constantino': 1082902869,
#  'Abraão Gourgel': 1080440646,
#  'Maria Monteiro Jardin': 1095470855,
#  'José da Rocha': 1094974511,
#  'Mateus de Brito Júnior': 1054271575,
#  'Kambamba Kulaxingo': 1093124425,
#  'Abel Xavier Nzuzi Lubota': 1080325199,
#  'David Mendes': 1024544204,
#  'Fernando Faustino Muteka': 1079490106,
#  'José Ndele': 1101583647,
#  'Daniel Ntongi-Nzinga': 848334573,
#  'Pedro Tonho Pedale': 1113903559,
#  'Elias Salupeto Pena': 994023688,
#  'Pinda Simão': 1115384278,
#  'Johnny Eduardo Pinnock': 992923654,
#  'Santana André Pitra': 886771177,
#  'José Aníbal Lopes Rocha': 985054758,
#  'Luís Gomes Sambo': 1114131425,
#  'José Filomeno dos Santos': 1111269228,
#  'Jonas Savimbi': 1110987217,
#  'Manuel Bernardo de Sousa': 886461023,
#  'Augusto da Silva Tomás': 1112407992,
#  'Luzia Inglês Van-Dúnem': 1067323463,
#  'Manuel Vicente': 1106406859,
#  'Mfulupinga Nlando Victor': 994085067,
#  'Randolph Beazer': 1094157275,
#  'Studiation Brown': 825090349,
#  "Colin O'Neil Browne": 1108425154,
#  'James Carlisle': 1112658085,
#  'Gail Christian': 1082380535,
#  'Osbert Richard Frederick': 1082381271,
#  'William Haynes-Smith': 1037116181,
#  'Tim Hector': 1075044001,
#  'Cheryl Mary Clare Hurst': 1082380270,
#  'Wilfred Jacobs': 1110866224,
#  'Harold Lovell': 1106157497,
#  'John Lyons (Antiguan politician)': 1102523754,
#  'Edmond Mansoor': 1106044619,
#  'Joanne Massiah': 1095742971,
#  'Melford Walter Nicholas': 1113392435,
#  'Bernard Percival': 1073473676,
#  'Alincia Williams-Grant': 1080767913,
#  'Joaquín Samuel de Anchorena': 1096421201,
#  'Juan Agustín Augier': 989941326,
#  'Uladislao Augier': 1083670137,
#  'Joaquín Belgrano': 1033486500,
#  'Antonio Bermejo': 1111012579,
#  'Antonio Beruti': 1072761348,
#  'Héctor Bidonde': 1091652004,
#  'Silvano Bores': 1035890502,
#  'Pedro Braillard Poccard': 1100848745,
#  'Exequiel Bustillo': 1096179751,
#  'Mario Cafiero': 1102185475,
#  'Alberto Manuel Campos': 1073206939,
#  'Alejo Castex': 1096414709,
#  'Dámaso Centeno': 1096183091,
#  'Carlos Corach': 1068148753,
#  'Jorge Coscia': 1099409991,
#  'Juan Carlos Del Bello': 1100037128,
#  'Luis L. Domínguez': 1089356576,
#  'Máximo Etchecopar': 1115155777,
#  'Héctor Toty Flores': 1067754685,
#  'Juan Fugl': 1073206214,
#  'Santiago Gallo': 1039135531,
#  'Manuel José García': 1007128573,
#  'Juan José Gómez Centurión': 1110844685,
#  'Luis Carlos Gómez Centurión': 1040878894,
#  'Martín Guzmán': 1111128923,
#  'Federico Helguera': 1066754349,
#  'Fernando Iglesias (Argentine politician)': 1093400021,
#  'Ricardo Kennedy': 1096426574,
#  'Carlos Kunkel': 1005790906,
#  'Norberto La Porta': 721029407,
#  'Andrés Larroque': 1060504858,
#  'Julián de Leyva': 959654287,
#  'Mónica López (politician)': 797826672,
#  'Lucio Victorio Mansilla': 1086339086,
#  'Nicolás Massot': 1069153148,
#  'Juan Mignaburu': 994878410,
#  'Guillermo Montenegro': 1096175549,
#  'Mariano Moreno': 1113829451,
#  'Marcelo Muniagurria': 1108926646,
#  'Fernando Nadra': 1105357958,
#  'Rómulo Sebastián Naón': 1096261399,
#  "Santiago G. O'Farrell": 1096261487,
#  'Miguel Ángel Pesce': 1096459313,
#  'Carlos Petroni': 1100374393,
#  'Alejo Peyret': 1091481103,
#  'Aldo Pignanelli': 1106856167,
#  'Enrique S. Quintana': 1016343362,
#  'Amán Rawson': 1096678788,
#  'Martín Sabbatella': 1073202733,
#  'Juan Pablo Schiavi': 1069152180,
#  'Héctor Tizón': 1096176230,
#  'Claudio Uberti': 1032047313,
#  'Arístides Villanueva': 994807413,
#  'Artashes Abeghyan': 1088583026,
#  'Aram Achekbashian': 1046857776,
#  'Hovsep Arghutian': 1095822812,
#  'Mikael Atabekyan': 1008108682,
#  'Tigran Bekzadyan': 1027604306,
#  'Vigen Chitechyan': 1099308421,
#  'Hayk Chobanyan': 1093711595,
#  'Daniel-Bek of Sassun': 1114419837,
#  'Gurgen Egiazaryan': 1103745376,
#  'Parunak Ferukhan': 1114420012,
#  'Hambardzum Galstyan': 1084735335,
#  'Gegham Gharibjanian': 1048485720,
#  'Gevorg Ghazaryan (politician)': 1082547991,
#  'Andrias Ghukasyan': 1108345283,
#  'Aram Grigoryan': 1112117000,
#  'Armen Grigoryan (politician)': 1069944070,
#  'Hayk Grigoryan': 1090623549,
#  'Grigor Jaghetyan': 1062820993,
#  'Tigran Karapetyan': 1112833785,
#  'Khachatur-Bek of Mush': 1114420639,
#  'Aram Kocharyan': 1107982644,
#  'Davit Lokyan': 1089241404,
#  'Hrant Maloyan': 1114902744,
#  'Khachatur Malumian': 1114420669,
#  'Aram Manukyan': 1048512708,
#  'Gevorg Melik-Karagyozyan': 980519720,
#  'Vahan Minakhoryan': 1055697655,
#  'Ruben Mirzakhanyan': 1084737845,
#  'Badal Muradyan': 1090630537,
#  'Gabriel Noradunkyan': 1114426086,
#  'Suren Papikyan': 1112772824,
#  'Paul Paul': 1114420707,
#  'Garo Paylan': 1104655518,
#  'Genrikh Poghosyan': 1085393392,
#  'Ishkhan Saghatelyan': 1107169295,
#  'Martiros Sarukhanyan': 933482772,
#  'Vartkes Serengülian': 1114426992,
#  'Serop Zakaryan': 1057547947,
#  'Servitchen': 1114420738,
#  'Suren Shadunts': 1109564586,
#  'Kasbar Sinabian': 1114426546,
#  'Ohannes Tchekidjian': 1090861179,
#  'Hrayr Tovmasyan': 993785842,
#  'Usuv Beg': 1086955149,
#  'Kegham Vanigian': 1114420793,
#  'Artak Zeynalyan': 1097086972,
#  'Alfons Adam': 1103541474,
#  'Ingo Appelt': 997950968,
#  'Baron Alexander von Bach': 1114355363,
#  'Maximilian Anton Karl, Count Baillet de Latour': 1112473939,
#  'Heinrich Alfred Barb': 1092809567,
#  'Raphael Basch': 1023595642,
#  'Leopold Berchtold': 1089443270,
#  'Hanns Blaschke': 1112474283,
#  'Andreas Bolek': 1005030653,
#  'Joseph Buttinger': 1080982386,
#  'Prince Carl of Solms-Braunfels': 1107215721,
#  'Count Wenzel Chotek of Chotkow and Wognin': 1083654825,
#  "Citizens' Ministry": 1071736555,
#  'Richard von Coudenhove-Kalergi': 1108787206,
#  'Karl von Czyhlarz': 1021127705,
#  'George Abraham von Dyhrn': 1007538469,
#  'Hans Ferlitsch': 941916920,
#  'Friedhelm Frischenschlager': 1018809630,
#  'Anton Füster': 1078570802,
#  'Julius Anton Glaser': 1112473750,
#  'Walter Guggenberger': 1112473762,
#  'Ulrich Habsburg-Lothringen': 1112474612,
#  'Ernst Hampel (politician)': 1069436586,
#  'Franz von Hartig': 1007537619,
#  'Hans Peter Haselsteiner': 1112603346,
#  'Friedrich Wilhelm von Haugwitz': 1112275892,
#  'Eduard Hedvicek': 1115494542,
#  'Eduard Herbst': 1007530580,
#  'Hermann Stern': 1101206070,
#  'Jürgen Himmelbauer': 969146003,
#  'Anton Hofer': 1105446235,
#  'Andreas Hörtnagl': 969145984,
#  'Franz Jetzinger': 1086163096,
#  'Konstantin Jireček': 1100601439,
#  'Hugo Jury': 1115504900,
#  'Maximilian Ulrich von Kaunitz': 1087172023,
#  'Joseph Kenner': 1112603390,
#  'Theodor Kery': 1065573627,
#  'Michael Killisch-Horn': 1106829544,
#  'Hubert Klausner': 1111898436,
#  'Martin Kocher': 1088269446,
#  'Józef Kożdoń': 1112603867,
#  'Jožef Krajnc': 1114850674,
#  'Hans Kudlich': 1048166289,
#  'Gottfried von Kühnelt-Leddihn': 1068422030,
#  'Hartmann Lauterbacher': 1070877897,
#  'Otto Lecher': 1033894166,
#  'Franz Leitner (politician)': 1010887552,
#  'Elmar Lichtenegger': 1058620648,
#  'Julius Lippert (historian)': 1084061853,
#  'Karl Lütgendorf': 1112474529,
#  'Jürgen Mandl': 977059921,
#  'Renate Mann': 1099978355,
#  'Ferdinand Mannlicher': 1104118829,
#  'Christoph Matznetter': 1105484317,
#  'Johann Gregor Memhardt': 1112474313,
#  'Franz Moroder': 1090940019,
#  'Heinz Nittel': 1109478769,
#  'Brigitta Pallauf': 1033512296,
#  'Wladimir von Pawlowski': 1019694668,
#  'Johann Anton von Pergen': 1061803495,
#  'Gerhard Pfanzelter': 1106125275,
#  'Walter Pfrimer': 1113533881,
#  'Ernst von Plener': 1017745075,
#  'Leopold Poetsch': 1092446707,
#  'Thomas Prinzhorn': 1112474168,
#  'Hermann von Ramberg': 994058910,
#  'Heinrich Reschauer': 1083947896,
#  'Horst Rosenkranz': 1112603574,
#  'Emil Sax': 1007521446,
#  'Karl Schmitzer': 1089049732,
#  'Georg Ritter von Schönerer': 1114549144,
#  'Georg Adam, Prince of Starhemberg': 1102889087,
#  'Gundaker Thomas Starhemberg': 1078907075,
#  'Josef Staribacher': 1049705609,
#  'Richard Steidle': 1112576338,
#  'Julius Tandler': 1077100690,
#  'Leopold, Count von Thun und Hohenstein': 1096753974,
#  'Muzio Tommasini': 1093955134,
#  'Karl Freiherr von Vogelsang': 1016446506,
#  'Max Winter (politician)': 1112474387,
#  'Anton von Winzor': 1045934334,
#  'Gisela Wurm': 1038160173,
#  'Alexander Zach': 1056085498,
#  'Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau': 1111962495,
#  'Karl von Zinzendorf': 1112603523,
#  'Muzamil Abdullayev': 1107065506,
#  'Leyla Abdullayeva': 1102138152,
#  'Elchin Afandiyev': 1075526613,
#  'Fazail Agamali': 1106843986,
#  'Fuad Alasgarov': 1018398706,
#  'Anvar Alikhanov': 1109309028,
#  'Tarlan Aliyarbayov': 1112064160,
#  'Dilara Aliyeva': 1109649588,
#  'Ali Asadov': 1112134949,
#  'Akram Aylisli': 1106344373,
#  'Sahil Babayev': 1112800095,
#  'Huseyngulu Baghirov': 1080007779,
#  'Alovsat Bakhshiyev': 1090036474,
#  'Rafael Kamil Dzhabrailov': 1100266382,
#  'Matin Eynullayev': 1110146340,
#  'Vilayat Eyvazov': 1109686454,
#  'Abdurrahman Fatalibeyli': 1094730548,
#  'Fazail Ibrahimli': 1096310851,
#  'Solomon Grobshtein': 1067081975,
#  'Teymur Guliyev': 1025325196,
#  'Mammad Gurbanov': 1101536288,
#  'Asaf Hajiyev': 1114198988,
#  'Farhad Hajiyev': 1109686109,
#  'Jamil Hasanli': 1091283791,
#  'Ali M. Hasanov': 1104973679,
#  'Shakir Hasanov': 1096145690,
#  'Zakir Hasanov': 1110113628,
#  'Ali Huseynli': 1090157253,
#  'Alisahib Huseynov': 1080007304,
#  'Ali Ibrahimov': 1067793317,
#  'Mammad Isgandarov': 1029087103,
#  'Vidadi Isgandarov': 1092547948,
#  'Ajdar Ismailov': 1096490381,
#  'Saftar Jafarov': 1045812028,
#  'Rovshan Javadov': 1108873335,
#  'Anar Karimov': 1109685880,
#  'Boris Kevorkov': 1072772142,
#  'Gurban Khalilov': 1094981152,
#  'Ahmad Kordary': 1093750341,
#  'Ilham Madatov': 1011331249,
#  'Musa Mammadov': 1084134498,
#  'Ramin Mammadov': 1020887005,
#  'Elshad Mirbashir oghlu': 1084157904,
#  'Fuad Naghiyev': 1081854289,
#  'Eldar Namazov': 1087483504,
#  'Siyavush Novruzov': 1114475460,
#  'Sadig Rahimov': 1074822020,
#  'Suleyman Rahimov': 1096039626,
#  'Huseyn Rahmanov': 1106104383,
#  'Hasan Sayidov': 1025325260,
#  'Parviz Shahbazov': 1105103095,
#  'Mammad agha Shahtakhtinski': 1080672703,
#  'Abid Sharifov': 1096574448,
#  'Bakhtiyar Vahabzadeh': 1114287934,
#  'Elmir Valiyev': 1074732244,
#  'Nurali Yusifbayli': 1019924574,
#  'Harold Christie': 1083155826,
#  'Timothy Donaldson': 1109457989,
#  'Joseph Robert Love': 1084382477,
#  'Mohammed Isa Al Abbasi': 1021088682,
#  'Abdullah bin Isa Al Khalifa': 1011511102,
#  'Ahmed Behzad (Bahrain)': 1063482737,
#  'Kamal Ahmed (politician)': 1010461395,
#  'Mohamed Ali Hasan Ali': 1006173162,
#  'Khalid Almoayed': 1063486161,
#  'Aymen Tawfeeq Almoayed': 1109935820,
#  'Nazar Al Baharna': 1067620253,
#  'Mahmood Al Bahrani': 1096789330,
#  'Ammar Al Bannai': 1089564533,
#  'Jawad Fairooz': 1088485834,
#  'Qasim Fakhro': 1099067663,
#  'Faisal al-Hamar': 1068897458,
#  'Nabeel bin Yaqub Al-Hamar': 1096789114,
#  'Isa bin Abdulrahman Al Hammadi': 1098344827,
#  'Jameel Humadan': 1003695133,
#  'Isa bin Ibrahim Al Khalifa': 1033132904,
#  'Fahmi al-Jowder': 1068744646,
#  'Saud Kanoo': 1098699647,
#  'Essam Khalaf': 1006167519,
#  'Abdullah bin Hamad bin Isa Al Khalifa': 1099004905,
#  'Ibrahim ibn Khalifa Al Khalifa': 1107463771,
#  'Mai bint Mohammed Al Khalifa': 1085733309,
#  'Khallfa bin Duaij Al Khalifa': 1022106863,
#  'Hamad Al Kooheji': 1096789043,
#  'Abdullatif Al-Mahmood': 1072499529,
#  'Khalid Al Maskati': 1096789192,
#  'Abdulhussain bin Ali Mirza': 1106388662,
#  'Mohammed Al-Buainain': 1063213013,
#  'Mohammed bin Khalifa bin Ahmed': 1087144216,
#  'Mohammed bin Khalifa bin Ali Al Khalifa': 1096789150,
#  'Abdulrahman al-Nuaimi': 1066056398,
#  'Ammar Qambar': 1086832849,
#  'Isa Qassim': 1100527312,
#  'Ahmed Al-Salloum': 1108146191,
#  'Salman bin Hamad Al Khalifa': 1109869774,
#  'Oli Ahad': 1076894174,
#  'Farid Ahmed': 1066581020,
#  'Muzaffar Ahmed (NAP politician)': 1109740890,
#  'AKM Hafizuddin': 1082571647,
#  'Mohammad Manjur Alam': 1099697606,
#  'Aftab Ali': 1111168357,
#  'M Hossain Ali': 1081670946,
#  'Ashab Uddin Ahmad': 1106492750,
#  'Selina Banu': 1059919387,
#  'Nurul Huq Bhuiyan': 1087353972,
#  'Bishnu Chattopadhyay': 1108066856,
#  'AKM Fazlul Kabir Chowdhury': 1115026757,
#  'Aminul Islam Chowdhury': 1068738297,
#  'Anwarul Karim Chowdhury': 1097570502,
#  'Moinuddin Ahmed Chowdhury': 1038606051,
#  'Sarwar Jan Chowdhury': 1052088875,
#  'Shahinur Pasha Chowdhury': 1102455717,
#  'Yusuf Ali Chowdhury': 1098197979,
#  'Haji Mohammad Danesh': 1090578062,
#  'Pulin De': 1038607348,
#  'James Leo Ferguson': 1098196717,
#  'Abdul Halim Ghaznavi': 1112056773,
#  'Debendra Nath Ghosh': 1110092316,
#  'Ranesh Das Gupta': 1038609480,
#  'AKM Fazlul Haque (Bangladeshi politician)': 1069141674,
#  'Abul Hashim': 1067903741,
#  'Syed Najmuddin Hashim': 1076061150,
#  'M. Anwar Hossain': 1049654323,
#  'Nozir Hossain': 1085128926,
#  'Syed Muhammad Ibrahim': 1113135652,
#  'Abul Kashem': 1094440759,
#  'Abul Kashem Khan': 1097883330,
#  'Hatem Ali Khan': 1085849741,
#  'Muhammad Hamidullah Khan': 1112460308,
#  'Yar Mohammad Khan': 1113198175,
#  'Jyotirindra Bodhipriya Larma': 1106007965,
#  'Manik Lal Ray': 1110874529,
#  'Mushrefa Mishu': 1066093324,
#  'Fazlul Haque Montu': 1107037359,
#  'Mujahidul Islam Selim': 1111837585,
#  'SM Nuruzzaman': 1068356533,
#  'Shamsul Huda Panchbagi': 1100820734,
#  'Muhammad Bayazeed Khan Panni': 1112344051,
#  'Ferdous Ahmed Qureshi': 1104814058,
#  'Abdur Rahim (scholar)': 1112109734,
#  'Habibar Rahman': 1045893159,
#  'M. M. Rahmatullah': 1107693597,
#  'Golam Maula Rony': 1113507548,
#  'Devasish Roy': 1112033318,
#  'Maulana Shakhawat': 1067136662,
#  'Zahidunnabi Dewan Shamim': 1093749046,
#  'Abul Kalam Shamsuddin': 1038585660,
#  'Badruddoza Ahmed Shuja': 1047850212,
#  'Mohammad Sultan': 1038605974,
#  'Mohammad Toaha': 1046006361,
#  'Badruddin Umar': 1111762930,
#  'Elliott Belgrave': 1110292983,
#  'Chad Blackman': 1113735930,
#  'Santia Bradshaw': 1097963495,
#  'Sonia Browne': 1080633319,
#  'Michael A. Carrington': 1090468579,
#  'William Fondleroy Duguid': 1086556181,
#  'Reginald Farley': 1090706976,
#  'Adrian Forde': 1079840895,
#  'Cynthia Y. Forde': 1106579042,
#  'Ian Gooding-Edghill': 1079872008,
#  'Damien K. A. Griffith': 996491794,
#  'Crystal Haynes': 1080792345,
#  'Hallam Henry (diplomat)': 1096826466,
#  'Philip St. Hill': 1096731562,
#  'Arthur Holder': 1090469580,
#  'Kirk Matthew Humphrey': 1079886049,
#  'Davidson Ishmael': 1079844213,
#  'Colin Everett Jordan': 1090593974,
#  'John Andrew King': 1079487466,
#  'Shantal Munro-Knight': 1080773405,
#  'Glyne Murray': 1096216109,
#  'Harry Scott Newlands': 1083147482,
#  "Charles Duncan O'Neal": 1091354442,
#  'Samuel Jackman Prescod': 1113474645,
#  'Shanika Roberts-Odle': 1080816111,
#  'Ryan Straughan': 1081912624,
#  'Dwight Sutherland': 1078282094,
#  'Kerrie Symmonds': 1109983886,
#  'Yury Ambrazevich': 1094141913,
#  'Lyavon Barshchewski': 975080643,
#  'Siarhei Cherachen': 1070934154,
#  'Zmitser Dashkevich': 1092550681,
#  'Siamion Domash': 1108538378,
#  'Tsimafei Dranchuk': 1115164729,
#  'Alaksandar Dubko': 1049964918,
#  'Alana Gebremariam': 1114832548,
#  'Gennady Grushevoy': 1094982832,
#  'Moshe Gutman': 1058221840,
#  'Uładzimir Hančaryk': 1105545058,
#  'Tamaš Hryb': 1089370903,
#  'Anatoĺ Kalinin': 1095765737,
#  'Uładzisłau Kazłouski': 1082906416,
#  'Pavel Pavlovich Kozlovsky': 1059698953,
#  'Ivan Kubrakov': 1110591101,
#  'Vladimir Kumets': 1107370274,
#  'Vyacheslav Nikolayevich Kuznetsov': 1059194181,
#  'Valery Levaneuski': 1103967180,
#  'Pavel Liohki': 1112377212,
#  'Uladzimir Mackievič': 1073431420,
#  'Vladimir Parfenovich': 1070648178,
#  'Jan Pazniak': 1109961050,
#  'Aleksandr Potupa': 1114686271,
#  'Pyotr Prakapovich': 1105481408,
#  'Alexander Radkov': 1091859585,
#  'Symon Rak-Michajłoŭski': 1108740902,
#  'Vladimir Vasilievich Rusakevich': 1100971465,
#  'Ihar Rynkevich': 1064451133,
#  'Aliaksandr Shakutsin': 1107954358,
#  'Nikolai Shelyagovich': 1092527212,
#  'Jan Stankievič': 1115330170,
#  'Mikola Statkevich': 1105528576,
#  'Sergei Tikhanovsky': 1115451955,
#  'Alaksandar Ćvikievič': 1113785358,
#  'Aleksandr Turchin': 1086196169,
#  'Franak Viačorka': 1110821628,
#  'Yury Voskresensky': 1091719034,
#  'Ivan Yermachenka': 1074131733,
#  'Manuel Abramowicz': 1063238122,
#  'Rudy Aernoudt': 1104528529,
#  'Herman Baltia': 1088797136,
#  'Jan Béghin': 1094288301,
#  'Frank Beke': 1076417124,
#  'Gustave Boël': 998374140,
#  'Pol Clovis Boël': 1044839682,
#  'Antoine Brun': 1105888595,
#  'Fernand Cocq': 1059781125,
#  'Émile Coulonvaux': 1058540019,
#  'Auguste Couvreur': 1058540061,
#  'Nico Cué': 1090780079,
#  'Pierre David (mayor)': 1055146012,
#  'August De Boodt': 1061093766,
#  'Dirk De fauw': 1054979701,
#  'René De Feyter': 995806187,
#  'François-Philippe de Haussy': 1087869295,
#  'Victor de Laveleye': 1077689317,
#  'Édouard Descamps': 1074405063,
#  'José Desmarets': 1059402951,
#  'Émile van Dievoet': 1109379888,
#  'Marc Drumaux': 1054937431,
#  'Jos Dupré': 1100264816,
#  'Françoise Dupuis': 1067685663,
#  'Veerle Geerinckx': 1048340504,
#  "Eugène Goblet d'Alviella": 1114852816,
#  'Jean-Pierre Grafé': 1112290249,
#  'Jacques Grippa': 1034055053,
#  'Guy Hance': 1058901086,
#  'Joris Helleputte': 1051591828,
#  'Lucienne Herman-Michielsens': 1073661185,
#  'Jules Hiernaux': 1003320218,
#  'Julius Hoste Jr.': 1080736243,
#  'Norbert Hougardy': 1058901497,
#  'Joseph Houssa': 1109576011,
#  'Vincent Houssiau': 1036198503,
#  'Pierre Van Humbeeck': 1058901725,
#  'Dorah Ilunga': 1106195369,
#  'Pierre Imperiali': 1058815544,
#  'Jean-François Istasse': 1104147247,
#  'Milou Jeunehomme': 1058898526,
#  'André Kempinaire': 1058897535,
#  'Willy Kuijpers': 1105018002,
#  'Rachid Madrane': 1094043509,
#  'Luc Michel': 1092518027,
#  'Fientje Moerman': 1089220103,
#  'André Molitor': 1089926878,
#  'Jean Pede': 1034055187,
#  'Jean-Marie Piret': 1102188001,
#  'André-Eugène Pirson': 1087847916,
#  "Philippe-Ambroise d'Olmen, Baron de Poederlé": 1030396425,
#  'Marjet Van Puymbroeck': 1090105907,
#  'Jean Richardot the Younger': 1085858301,
#  'Gustave Rolin-Jaequemyns': 1103791996,
#  'Hippolyte Rolin': 1029822060,
#  'Father Samuel': 1105406687,
#  'Louis-Joseph Seutin': 1067673529,
#  'Alfons Siffer': 1044386557,
#  'Cyrille Tahay': 1099406349,
#  'Jacques Timmermans': 1099978512,
#  'Robert Urbain': 1073906467,
#  'Jacques Van Gompel': 994051445,
#  'Marcel Van Langenhove (referee)': 1107440236,
#  'Johan Verbeke': 1096587032,
#  'Lodewijk Verreycken': 1104711170,
#  'Louis Waltniel': 1058900581,
#  'Yves de Wasseige': 1099711000,
#  'Jacques van Ypersele de Strihou': 1101784212,
#  'Beverly Castillo': 919973607,
#  'Elfreda Reyes': 1036465539,
#  'Bert Tucker': 1106473958,
#  'Michel Ahouanmènou': 1082795168,
#  'Arnauld Antoine Akodjènou': 1096094495,
#  'Jules-Armand Aniambossou': 1083426767,
#  'Pascal Chabi Kao': 1085346521,
#  'Francis Covi': 1067482687,
#  'Joachim Dahissiho': 1029448695,
#  'Adrien Degbey': 1061050724,
#  'Luc Gnacadja': 1105462246,
#  'Paul Hazoumé': 1103078061,
#  'Louis Hunkanrin': 1093387515,
#  'Louis Ignacio-Pinto': 1092475356,
#  'Arouna Mama': 1065903499,
#  'Moussa Okanla': 1090050440,
#  'Assogba Oké': 1086957528,
#  'Émile Poisson': 1084137581,
#  'Maximilien Quenum-Possy-Berry': 1043722585,
#  'Nicéphore Soglo': 1095045396,
#  'Dorjee Wangmo': 1060085965,
#  'Ugyen Dorji (DNT politician)': 1074573786,
#  'Zangley Dukpa': 1068932528,
#  'Dupthob': 986218104,
#  'Pema Gyamtsho': 1110797584,
#  'Choki Gyeltshen': 967051066,
#  'Sherub Gyeltshen': 1069232338,
#  'Choida Jamtsho': 1100668369,
#  'Rinzin Jamtsho': 986219619,
#  'Kunzang C. Namgyel': 1115406312,
#  'Shingkhar Lam': 1065108391,
#  'Tshewang Lhamo': 935053684,
#  'Kuenga Loday': 967051092,
#  'Dorji Namgyal': 1101249209,
#  'Jigme Namgyal (Bhutan)': 1112477163,
#  'Wangdi Norbu': 1099185991,
#  'Kinga Penjor': 1029727171,
#  'Yeshey Penjor': 956623702,
#  'Thakur S. Powdyel': 1113475126,
#  'Jai Bir Rai': 1099839823,
#  'Karma Rangdol': 986221796,
#  'Loknath Sharma': 1099839678,
#  'Tenzin (politician)': 1017464973,
#  'Sonam Tobgye': 1088131266,
#  'Dorji Tshering': 1023360934,
#  'Kinga Tshering': 1111838853,
#  'Namgay Tshering': 1062630670,
#  'Ugyen Tshering': 1068931844,
#  'Jigme Wangchuk': 1076705305,
#  'Lhatu Wangchuk': 1077117615,
#  'Khandu Wangchuk': 1082071070,
#  'Norbu Wangchuk': 1105642733,
#  'Tshering Wangchuk': 1098122862,
#  'Karma Donnen Wangdi': 1013757910,
#  'Tshencho Wangdi': 935053725,
#  'Ugyen Wangdi': 1010522641,
#  'Dechen Wangmo (politician)': 1109945331,
#  'Dechen Zangmo': 1095618727,
#  'Neten Zangmo': 1087879345,
#  'Nidup Zangpo': 1083086732,
#  'Yeshey Zimba': 1082071369,
#  'Nataniel Aguirre': 1113064273,
#  'Jacobo Aillón': 1066796299,
#  'Isaac Ávalos': 1105448251,
#  'Augusto Céspedes': 1060109299,
#  'Soledad Chapetón': 1100789033,
#  'Adolfo Chávez': 1064862832,
#  'Chi Hyun Chung': 1102263683,
#  'Daniel Sánchez Bustamante': 1112693678,
#  'Rafael Peña': 1106083763,
#  'Marcial Fabricano': 1064844718,
#  'Francisco Argandoña': 1113998869,
#  'Antonio Machaca': 1104152307,
#  'Adolfo Mendoza': 1093449967,
#  'Pedro Domingo Murillo': 1102892437,
#  "Francisco Burdett O'Connor": 1115492398,
#  'Manuel Luis de Oliden': 1111940891,
#  'Isabel Ortega Ventura': 1067118559,
#  'Simón Iturri Patiño': 1113483466,
#  'Bonifacio Pinedo': 1013870027,
#  'Julio Pinedo': 1013509802,
#  'José Mariano Serrano': 1102912474,
#  'Moisés Torres (politician)': 1103547860,
#  'Fernando Vargas Mosua': 1113961954,
#  'Jaime de Zudáñez': 1057374473,
#  'Elvira Abdić-Jelenović': 1092410267,
#  'Mehmed Alajbegović': 1090097632,
#  'Boško Baškot': 945729760,
#  'Hasan Brkić': 1108766075,
#  'Salko Bukvarević': 1103476585,
#  'Mirsad Ćeman': 1059620444,
#  'Selmo Cikotić': 1109891116,
#  'Sabina Ćudić': 1109170821,
#  'Milorad Dodik': 1115334252,
#  'Dženan Đonlagić': 1023971751,
#  'Nijaz Duraković': 1115514419,
#  'Edin Forto': 1114128635,
#  'Dževad Galijašević': 1080524051,
#  'Josip Grubeša': 1078976634,
#  'Ankica Gudeljević': 1109892248,
#  'Muhamed Hadžijamaković': 1069745508,
#  'Mirsad Hadžikadić': 1114039434,
#  'Sanjin Halimović': 1098646648,
#  'Husein Miljković': 1098413355,
#  'Jasmin Imamović': 1060821223,
#  'Alija Izetbegović': 1114046666,
#  'Adamir Jerković': 1070639895,
#  'Esed Kadrić': 1099964892,
#  'Mehmed Kapetanović': 1074875734,
#  'Salmir Kaplan': 1095054536,
#  'Osman Karabegović': 1027401183,
#  'Fuad Kasumović': 1083608363,
#  'Rudi Kolak': 1059610572,
#  'Ivo Komšić': 1114461162,
#  'Rusmir Mahmutćehajić': 1101508210,
#  'Ante Marković': 1107391428,
#  'Amor Mašović': 1060006575,
#  'Dragan Mektić': 1115510719,
#  'Ademaga Mešić': 1095848757,
#  'Jelka Miličević': 1040936683,
#  'Abdulah Mutapčić': 1006720652,
#  'Abdulah Nakaš': 1102636519,
#  'Mario Nenadić': 1111446400,
#  'Damir Nikšić': 1096462723,
#  'Ismet Popovac': 1115247176,
#  'Hakija Pozderac': 963175504,
#  'Hamdija Pozderac': 1045803709,
#  'Nurija Pozderac': 1056889716,
#  'Đuro Pucar': 1052519383,
#  'Fahrudin Radončić': 1101596243,
#  'Alen Šeranić': 1111537511,
#  'Uglješa Uzelac': 1003796992,
#  'Nezir Škaljić': 1107435418,
#  'Ibrahim Spahić': 995023876,
#  'Emir Suljagić': 1065740656,
#  'Svetozar Pudarić': 1107151585,
#  'Miloš Vukašinović': 934652983,
#  'Daniel Kwele': 1084843766,
#  'Michael Dingake': 1084856043,
#  'James G. Haskins': 1089282280,
#  'Tshenolo Mabeo': 1084860922,
#  'Philip Matante': 1084858391,
#  'Gomolemo Motswaledi': 1092621711,
#  'Motsamai Mpho': 1056631444,
#  'Sylvia Muzila': 1092977456,
#  'Leetile Disang Raditladi': 1102718757,
#  'Benjamin Thema': 1089085673,
#  'Patrick van Rensburg': 1113094894,
#  'Maria de Lourdes Abadia': 1111422727,
#  'José de Abreu (politician)': 1097490839,
#  'Rafael Tobias de Aguiar': 1074741594,
#  'Medeiros e Albuquerque': 1097328483,
#  'Léo de Almeida Neves': 1101145934,
#  'Simão Almeida': 1099633172,
#  'Antônio Pinto Chichorro da Gama': 1096806594,
#  'Cipriano Barata': 1107774158,
#  'Irani Barbosa': 1101926106,
#  'Jaison Barreto': 1103547503,
#  'Djalma Bastos de Morais': 1106062579,
#  'Henrique de Beaurepaire-Rohan, Viscount of Beaurepaire-Rohan': 1086322080,
#  'José Paulo Bisol': 1103547561,
#  'Natália Bastos Bonavides': 1110953316,
#  'João Francisco Inácio Brazão': 1094855099,
#  'Amador Bueno': 1034472026,
#  'Antônio Câmara': 1099829944,
#  'Luiz Humberto Carneiro': 1098842373,
#  'Izolda Cela': 1102485000,
#  'Margarete Coelho': 1103498671,
#  'Ivandro Cunha Lima': 1098295043,
#  'João Cunha (politician)': 1100962574,
#  'Aécio de Borba': 1098281596,
#  'José Abílio Silva de Santana': 1112293020,
#  'Alércio Dias': 1101206546,
#  'Délio dos Santos': 1101206499,
#  'Ademar Frederico Duwe': 1098597920,
#  'Elcione Zahluth Barbalho': 1074736382,
#  "Gastão d'Escragnolle, Baron d'Escragnolle": 1063661693,
#  'Paulo Cesar Farias': 1065573695,
#  'Emília Fernandes': 1078521692,
#  'José Carlos da Silva Mayrink Ferrão': 1085435249,
#  'Dalva Figueiredo': 1087607148,
#  'Francisco Julião': 1035689740,
#  'Jofran Frejat': 1102181607,
#  'Edmundo Galdino': 1112253425,
#  'Joaquim Gomes de Souza': 1069184517,
#  'Abdul Hamid Sebba': 1111084208,
#  'Jutahy Júnior': 983207788,
#  'Joaquim Gonçalves Ledo': 1071023786,
#  'Antônio Leite Andrade': 1101206516,
#  'Alceste Madeira': 1099410153,
#  'Beto Mansur': 1113576505,
#  'Horácio de Matos': 1088164926,
#  'Sandra Meira Starling': 1099835037,
#  'Gerardo Melo Mourão': 1098005745,
#  'Guilherme Melo (politician)': 1099445119,
#  'Murilo Melo Filho': 1102568805,
#  'Cândido Mendes de Almeida': 1097155280,
#  'Gilmar Mendes': 1106136142,
#  'Edmur Mesquita': 1094838035,
#  'Miguel Couto': 1035994107,
#  'Claudio Modesto': 994272220,
#  'Armando Monteiro (politician)': 1098295517,
#  'Carlos Eduardo Moreira Ferreira': 1087824575,
#  'Pedro Soares Muñoz': 1096764969,
#  'Dora Nascimento': 1028740301,
#  'Carlos Neder': 1102908883,
#  'Domingos Gomes de Aguiar Neto': 1109245420,
#  'Manuel Luís Osório, Marquis of Erval': 1110318599,
#  'Hildebrando Pascoal': 1088472912,
#  'Astrojildo Pereira': 1083304045,
#  'Joaquim Alvaro Pereira Leite': 1114125901,
#  'Jorge Picciani': 1099308847,
#  'Francisco José Pinheiro': 1089344947,
#  'Mario Pinotti': 1033871516,
#  'Henrique Pizzolato': 940662779,
#  'Plínio de Arruda Sampaio Jr.': 1100471665,
#  'Irondi Pugliesi': 1111085644,
#  'Eusébio de Queirós': 1091204382,
#  'Ratinho (TV presenter)': 1114298116,
#  'Marco Antonio Raupp': 1098664390,
#  'Robert Rey (plastic surgeon)': 1112518148,
#  'Ary Rigo': 1100211750,
#  'Antônio Ricardo dos Santos': 1028742803,
#  'Euclides Scalco': 1101357504,
#  ...}

# %% [markdown]
# Now that we have the last revision ID for each article, we can now request their respective score from the ORES API endpoint

# %%
#########
#
#    CONSTANTS
#

# The current ORES API endpoint
API_ORES_SCORE_ENDPOINT = "https://ores.wikimedia.org/v3"
# A template for mapping to the URL
API_ORES_SCORE_PARAMS = "/scores/{context}/{revid}/{model}"

# Use some delays so that we do not hammer the API with our requests
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<uwnetid@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2022'
}


# This template lists the basic parameters for making an ORES request
ORES_PARAMS_TEMPLATE = {
    "context": "enwiki",        # which WMF project for the specified revid
    "revid" : "",               # the revision to be scored - this will probably change each call
    "model": "articlequality"   # the AI/ML scoring model to apply to the reviewion
}
#
# The current ML models for English wikipedia are:
#   "articlequality"
#   "articletopic"
#   "damaging"
#   "version"
#   "draftquality"
#   "drafttopic"
#   "goodfaith"
#   "wp10"
#
# The specific documentation on these is scattered so if you want to use one you'll have to look around.
#

# %% [markdown]
# The API request will be made using one procedure. The idea is to make this reusable. The procedure is parameterized, but relies on the constants above for the important parameters. The underlying assumption is that this will be used to request data for a set of article revisions. Therefore, the main parameter is article_revid.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, 
                                   endpoint_url = API_ORES_SCORE_ENDPOINT, 
                                   endpoint_params = API_ORES_SCORE_PARAMS, 
                                   request_template = ORES_PARAMS_TEMPLATE,
                                   headers = REQUEST_HEADERS,
                                   features=False):
    # Make sure we have an article revision id
    if not article_revid: return None
    
    # set the revision id into the template
    request_template['revid'] = article_revid
    
    # now, create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_params.format(**request_template)
    
    # the features used by the ML model can sometimes be returned as well as scores
    if features:
        request_url = request_url+"?features=true"
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# We send a request per article and store the data obtained in a dictionary called ARTICLE_SCORES. Any article that does not have a score or incurred in an error is stored in the list ARTICLE_SCORES_NULL

# %%
ARTICLE_SCORES = {}
ARTICLE_SCORES_NULL =[]
for article, last_rev_id in ARTICLE_REVISIONS.items():
    score = request_ores_score_per_article(last_rev_id)
    if score['enwiki']["scores"][str(ARTICLE_REVISIONS[article])]['articlequality']['score'].get('prediction','null') != 'null':
        classification = score['enwiki']["scores"][str(ARTICLE_REVISIONS[article])]['articlequality']['score']['prediction']
        ARTICLE_SCORES[article] = classification
    else:
        ARTICLE_SCORES_NULL.append(article)

# %%
ARTICLE_SCORES
# Out:
# {'Shahjahan Noori': 'GA',
#  'Abdul Ghafar Lakanwal': 'Start',
#  'Majah Ha Adrif': 'Start',
#  'Haroon al-Afghani': 'B',
#  'Tayyab Agha': 'Start',
#  'Ahmadullah Wasiq': 'Start',
#  'Aziza Ahmadyar': 'Start',
#  'Muqadasa Ahmadzai': 'Start',
#  'Mohammad Sarwar Ahmedzai': 'Start',
#  'Amir Muhammad Akhundzada': 'Start',
#  'Nasrullah Baryalai Arsalai': 'Start',
#  'Mohammad Asim Asim': 'Stub',
#  'Atiqullah Atifmal': 'Start',
#  'Abdul Rahim Ayoubi': 'Start',
#  'Alhaj Mutalib Baig': 'Start',
#  'Ismael Balkhi': 'Start',
#  'Abdul Baqi Turkistani': 'Stub',
#  'Mohammad Ghous Bashiri': 'Start',
#  'Abas Basir': 'C',
#  'Jan Baz': 'Stub',
#  'Ahmad Behzad': 'Start',
#  'Bashir Ahmad Bezan': 'Start',
#  'Rafiullah Bidar': 'Stub',
#  'Mohammad Siddiq Chakari': 'Stub',
#  'Cheragh Ali Cheragh': 'Start',
#  'Nasir Ahmad Durrani': 'Stub',
#  'Elay Ershad': 'Stub',
#  'Muhammad Hashim Esmatullahi': 'Stub',
#  'Ezatullah (Nangarhar)': 'Stub',
#  'Aimal Faizi': 'Stub',
#  'Mohammad Nasim Faqiri': 'Start',
#  'Mohammad Nazar Faqiri': 'Stub',
#  'Sharif Ghalib': 'B',
#  'Hashmat Ghani Ahmadzai': 'C',
#  'Abdul Ghani Ghani': 'Stub',
#  'Ashraf Ghani': 'B',
#  'Abdul Samad Ghaus': 'Stub',
#  'Ghulam Ghaus': 'Stub',
#  'Ghulam Muhammad Ghobar': 'Stub',
#  'Mohammad Gul (Helmand Council)': 'Stub',
#  'Ghulam Haider Hamidi': 'Start',
#  'Rangina Hamidi': 'C',
#  'Abdul Malik Hamwar': 'Stub',
#  'Sayed Zafar Hashemi': 'Start',
#  'Qutbuddin Hilal': 'Start',
#  'Shahnaz Himmeti': 'Stub',
#  'Anarkali Kaur Honaryar': 'Start',
#  'Mahboba Hoqomal': 'Stub',
#  'Musa Hotak': 'Start',
#  'Mirza Muhammad Ismail': 'C',
#  'Sayed Jalal': 'Start',
#  'Said Tayeb Jawad': 'C',
#  'Faizullah Kakar': 'C',
#  'Amin Karim': 'C',
#  'Sayed Jalal Karim': 'Start',
#  'Ahmed Wali Karzai': 'GA',
#  'Khadija Zahra Ahmadi': 'Stub',
#  'Hafizullah Shabaz Khail': 'Start',
#  'Rouh Gul Khairzad': 'Stub',
#  'Masoud Khalili': 'GA',
#  'Mohammad Khan (athlete)': 'Stub',
#  'Samoud Khan': 'Start',
#  'Farzana Kochai': 'Stub',
#  'Farida Kuchi': 'Start',
#  'Baran Khan Kudezai': 'Start',
#  'Azizullah Lodin': 'Start',
#  'Razaq Mamoon': 'Start',
#  'Fazel Ahmed Manawi': 'Stub',
#  'Moeen Marastial': 'Start',
#  'Ahmad Massoud': 'C',
#  'Ahmad Wali Massoud': 'Start',
#  'Mohammad Daud Miraki': 'C',
#  'Abdul Sattar Mirzakwal': 'Stub',
#  'Abdul Karim Misaq': 'Stub',
#  'Ali Mohammad (politician)': 'Stub',
#  'Nasruddin Mohseni': 'Start',
#  'Davood Moradian': 'Stub',
#  'Zalmai Mujadidi': 'Start',
#  'Fazal Haq Mujahid': 'C',
#  'Rahmatullah Nabil': 'Start',
#  'Sardar Mohammad Nadir Naeem': 'Stub',
#  'Daoud Naji': 'Start',
#  'Gholam Rabani Nasher': 'Stub',
#  'Muhammad Yunus Nawandish': 'C',
#  'Ali Maisam Nazary': 'Start',
#  'Ghulam Faroq Nijrabi': 'Stub',
#  'Zabih-U-llah Ghazi Noristani': 'Start',
#  'Mohammed Tahir Omar': 'Stub',
#  'Nasrin Oryakhil': 'Start',
#  'Murad Quenili': 'Stub',
#  'Ghulam Mohammad Rigi': 'Stub',
#  'Ghulam Hassan Safi': 'Stub',
#  'Hanifa Safi': 'Stub',
#  'Amrullah Saleh': 'FA',
#  'Mohammed Zia Salehi': 'Stub',
#  'Abdul Majid Samim': 'Stub',
#  'Saber Sangar': 'Stub',
#  'Muhammad Arif Sarwari': 'Start',
#  'Sayed Nasim Mihanparast': 'Stub',
#  'Sayyid Husayn': 'Stub',
#  'Suhail Shaheen': 'Start',
#  'Mohammad Shakir Kargar': 'C',
#  'Baktash Siawash': 'Stub',
#  'Awtar Singh': 'Stub',
#  'Hasan Ali Sultani': 'Stub',
#  'Faramarz Tamanna': 'C',
#  'Mohammad Hashem Taufiqui': 'Start',
#  'Nur ul-Haq Ulumi': 'GA',
#  'Pacha Gul Wafadar': 'Stub',
#  'Wahidullah Waissi': 'C',
#  'Gul Ahmmad Yama': 'Start',
#  'Al-Haj Suliman Yari': 'Stub',
#  'Abdul Salam Zaeef': 'GA',
#  'Abdul Zahir (Konar Education Minister)': 'Stub',
#  'Mohammed Zaman': 'Start',
#  'Ziauddin (Afghan militia leader)': 'Start',
#  'Qari Ziauddin': 'Start',
#  'Abdul Ghafor Zori': 'Stub',
#  'Ali Pasha of Gusinje': 'GA',
#  'Ylli Asllani': 'Start',
#  'Azis Tahir Ajdonati': 'Stub',
#  'Bislim Bajgora': 'Start',
#  'Kastriot Berissa': 'Start',
#  'Bardhok Biba': 'C',
#  'Dervish Biçaku': 'Stub',
#  'Kostandin Boshnjaku': 'C',
#  'Spartak Braho': 'Start',
#  'Safet Butka': 'C',
#  'Uran Butka': 'Start',
#  'Refo Çapari': 'Start',
#  'Neritan Ceka': 'Start',
#  'Hysni Curri': 'Start',
#  'Ibrahim Dalliu': 'Start',
#  'Niazi Demi': 'Stub',
#  'Abdurrahman Dibra': 'Start',
#  'Fuad Dibra': 'Start',
#  'Isuf Dibra': 'Start',
#  'Bujar Dida': 'C',
#  'Ahmed Dino': 'Stub',
#  'Rasih Dino': 'Stub',
#  'Ferhat Bey Draga': 'C',
#  'Nexhip Draga': 'GA',
#  'Aqif Pasha Elbasani': 'B',
#  'Abas Ermenji': 'Start',
#  'Bajram Fevziu': 'Start',
#  'Qamil Musa Haxhi Feza': 'Stub',
#  'Themistokli Gërmenji': 'C',
#  'Sabri Godo': 'C',
#  'Mihal Grameno': 'C',
#  'Aćif Hadžiahmetović': 'GA',
#  'Albulena Haxhiu': 'Stub',
#  'High Council of Regency': 'C',
#  'Spiridon Kacarosi': 'Stub',
#  'Kurt Agë Kadiu': 'Stub',
#  'Mehmed Kalakula': 'Stub',
#  'Alfred Karamuço': 'Stub',
#  'Ibrahim Karbunara': 'Start',
#  'Ali Këlcyra': 'C',
#  'Belind Këlliçi': 'C',
#  'Bajram Kelmendi': 'Start',
#  'Kristo Kirka': 'C',
#  'Elez Koçi': 'Start',
#  'Ali Riza Kolonja': 'Start',
#  'Glauk Konjufca': 'Start',
#  'Xhelal Koprëncka': 'Stub',
#  'Kryeziu family': 'Start',
#  'Artur Kuko': 'Stub',
#  'Xhavid Leskoviku': 'Start',
#  'Sabit Lulo': 'Stub',
#  'Gjon Markagjoni': 'C',
#  'Tefik Mborja': 'Start',
#  'Fatmir Mediu': 'Stub',
#  'Hysni Milloshi': 'Start',
#  'Musa Qazimi': 'GA',
#  'Mustafa Ndroqi': 'Stub',
#  'Behxhet Nepravishta': 'Stub',
#  'Adrian Neritani': 'Start',
#  'Sali Nivica': 'Start',
#  'Thoma Orologa': 'Start',
#  'Bedri Pejani': 'C',
#  'Pertef Pogoni': 'Stub',
#  'Kadri Prishtina': 'Start',
#  'Ymer Prizreni': 'Start',
#  'Avni Rustemi': 'C',
#  'Chatin Sarachi': 'C',
#  'Nebi Sefa': 'Stub',
#  'Eduard Shalsi': 'Start',
#  'Ylli Vesel Shehu': 'Stub',
#  'Athanas Shundi': 'B',
#  'Xhelal Sveçla': 'Start',
#  'Mehmet Tahsini': 'Stub',
#  'Ibrahim Temo': 'GA',
#  'Pavli Terka': 'Start',
#  'Afrim Tole': 'Stub',
#  'Sejfi Vllamasi': 'Start',
#  'Syrja Vlora': 'Start',
#  'Visarion Xhuvani': 'C',
#  'Visar Ymeri': 'Stub',
#  'Abdyl Ypi': 'Stub',
#  'Xhezair Zaganjori': 'Start',
#  'Menduh Zavalani': 'GA',
#  'Said Abadou': 'Stub',
#  'Tahar Allan': 'Stub',
#  'Mohamed Seghir Babes': 'Stub',
#  'Djelloul Baghli': 'Stub',
#  'Noureddine Bahbouh': 'Stub',
#  'Lamine Bechichi': 'Stub',
#  'Bakhti Belaïb': 'Stub',
#  'Mohamed Belouizdad': 'Start',
#  'Mourad Benachenou': 'Stub',
#  'Benaouda Hadj Hacène Bachterzi': 'Stub',
#  'Souad Bendjaballah': 'Stub',
#  'Mohammed Saleh Bendjelloul': 'Stub',
#  'Mohamed Bensalam': 'Stub',
#  'Said Boualam': 'Start',
#  'Abdeslam Bouchouareb': 'Stub',
#  'Brahim Chibout': 'Stub',
#  'Bouras Djamel': 'Stub',
#  'Ahmed Djebbar': 'Stub',
#  'Fatiha Serour': 'Start',
#  'Mohamed Hassaïne': 'C',
#  'Ibrahim Boughali': 'Stub',
#  'Abdenour Keramane': 'Stub',
#  'Abelkader Khamri': 'Stub',
#  'Mahmoud Khedri': 'Stub',
#  'Mohamed Laïchoubi': 'Stub',
#  'Sassi Lamouri': 'Stub',
#  'Mohamed Maghlaoui': 'Stub',
#  'Amar Makhloufi': 'Stub',
#  'Hacen Mefti': 'Stub',
#  'Mokhtar Meherzi': 'Stub',
#  'Mohamed Elias Mesli': 'Stub',
#  'Azzedine Mihoubi': 'Start',
#  'Cherif Rahmani': 'Stub',
#  'Naima Salhi': 'Stub',
#  "Guillem d'Areny-Plandolit": 'FA',
#  'Guillem Areny': 'Stub',
#  'Joan Armengol': 'Stub',
#  'Francesc Badia Batalla': 'Stub',
#  'Josep Maria Beal': 'Stub',
#  'Climent Palmitjavila': 'Stub',
#  'Antoni Puigdellívol': 'Start',
#  'Òscar Ribas Reig': 'C',
#  'Boris Skossyreff': 'GA',
#  'Enric Tarrado Vives': 'Stub',
#  'Alexandre Sebastião André': 'Stub',
#  'Isaac Maria dos Anjos': 'Stub',
#  'Paulino Baptista': 'Start',
#  'João Baptista Borges': 'Start',
#  'Branca Manuel Espirito Santo': 'Stub',
#  'André Luís Brandão': 'Stub',
#  'André Gaspar Mendes de Carvalho': 'Stub',
#  'Carolina Cerqueira': 'C',
#  'Arlete Chimbinda': 'Start',
#  'Kafundanga Chingunji': 'Stub',
#  'Jeremias Chitunda': 'Start',
#  'Abel Chivukuvuku': 'Start',
#  'Adalberto Costa Júnior': 'Stub',
#  'Adjany Costa': 'Start',
#  'Álvaro Arnaldo Craveiro': 'Stub',
#  'Raul Danda': 'Stub',
#  'Carlos António Fernandes': 'Stub',
#  'Fiel Domingos Constantino': 'Stub',
#  'Abraão Gourgel': 'Stub',
#  'Maria Monteiro Jardin': 'Stub',
#  'José da Rocha': 'Stub',
#  'Mateus de Brito Júnior': 'Stub',
#  'Kambamba Kulaxingo': 'Stub',
#  'Abel Xavier Nzuzi Lubota': 'Stub',
#  'David Mendes': 'Stub',
#  'Fernando Faustino Muteka': 'Stub',
#  'José Ndele': 'Stub',
#  'Daniel Ntongi-Nzinga': 'Stub',
#  'Pedro Tonho Pedale': 'Stub',
#  'Elias Salupeto Pena': 'Stub',
#  'Pinda Simão': 'Stub',
#  'Johnny Eduardo Pinnock': 'Stub',
#  'Santana André Pitra': 'Stub',
#  'José Aníbal Lopes Rocha': 'Stub',
#  'Luís Gomes Sambo': 'Start',
#  'José Filomeno dos Santos': 'Start',
#  'Jonas Savimbi': 'C',
#  'Manuel Bernardo de Sousa': 'Stub',
#  'Augusto da Silva Tomás': 'Stub',
#  'Luzia Inglês Van-Dúnem': 'Start',
#  'Manuel Vicente': 'C',
#  'Mfulupinga Nlando Victor': 'Start',
#  'Randolph Beazer': 'Stub',
#  'Studiation Brown': 'Stub',
#  "Colin O'Neil Browne": 'Stub',
#  'James Carlisle': 'C',
#  'Gail Christian': 'Start',
#  'Osbert Richard Frederick': 'Start',
#  'William Haynes-Smith': 'C',
#  'Tim Hector': 'C',
#  'Cheryl Mary Clare Hurst': 'Stub',
#  'Wilfred Jacobs': 'Stub',
#  'Harold Lovell': 'Start',
#  'John Lyons (Antiguan politician)': 'C',
#  'Edmond Mansoor': 'Stub',
#  'Joanne Massiah': 'Stub',
#  'Melford Walter Nicholas': 'Start',
#  'Bernard Percival': 'Stub',
#  'Alincia Williams-Grant': 'Start',
#  'Joaquín Samuel de Anchorena': 'Start',
#  'Juan Agustín Augier': 'Stub',
#  'Uladislao Augier': 'Stub',
#  'Joaquín Belgrano': 'Start',
#  'Antonio Bermejo': 'Start',
#  'Antonio Beruti': 'Start',
#  'Héctor Bidonde': 'Start',
#  'Silvano Bores': 'Stub',
#  'Pedro Braillard Poccard': 'Stub',
#  'Exequiel Bustillo': 'Stub',
#  'Mario Cafiero': 'Stub',
#  'Alberto Manuel Campos': 'Start',
#  'Alejo Castex': 'C',
#  'Dámaso Centeno': 'Stub',
#  'Carlos Corach': 'Stub',
#  'Jorge Coscia': 'Stub',
#  'Juan Carlos Del Bello': 'Stub',
#  'Luis L. Domínguez': 'C',
#  'Máximo Etchecopar': 'Start',
#  'Héctor Toty Flores': 'Stub',
#  'Juan Fugl': 'Stub',
#  'Santiago Gallo': 'Start',
#  'Manuel José García': 'Stub',
#  'Juan José Gómez Centurión': 'Stub',
#  'Luis Carlos Gómez Centurión': 'Stub',
#  'Martín Guzmán': 'C',
#  'Federico Helguera': 'Start',
#  'Fernando Iglesias (Argentine politician)': 'C',
#  'Ricardo Kennedy': 'Stub',
#  'Carlos Kunkel': 'Stub',
#  'Norberto La Porta': 'Stub',
#  'Andrés Larroque': 'Start',
#  'Julián de Leyva': 'Stub',
#  'Mónica López (politician)': 'Stub',
#  'Lucio Victorio Mansilla': 'Start',
#  'Nicolás Massot': 'Start',
#  'Juan Mignaburu': 'Stub',
#  'Guillermo Montenegro': 'Stub',
#  'Mariano Moreno': 'B',
#  'Marcelo Muniagurria': 'Stub',
#  'Fernando Nadra': 'C',
#  'Rómulo Sebastián Naón': 'Start',
#  "Santiago G. O'Farrell": 'Start',
#  'Miguel Ángel Pesce': 'Start',
#  'Carlos Petroni': 'C',
#  'Alejo Peyret': 'B',
#  'Aldo Pignanelli': 'Stub',
#  'Enrique S. Quintana': 'Start',
#  'Amán Rawson': 'Start',
#  'Martín Sabbatella': 'C',
#  'Juan Pablo Schiavi': 'C',
#  'Héctor Tizón': 'Start',
#  'Claudio Uberti': 'C',
#  'Arístides Villanueva': 'Start',
#  'Artashes Abeghyan': 'Start',
#  'Aram Achekbashian': 'Stub',
#  'Hovsep Arghutian': 'Start',
#  'Mikael Atabekyan': 'Stub',
#  'Tigran Bekzadyan': 'Stub',
#  'Vigen Chitechyan': 'Stub',
#  'Hayk Chobanyan': 'Start',
#  'Daniel-Bek of Sassun': 'Start',
#  'Gurgen Egiazaryan': 'Start',
#  'Parunak Ferukhan': 'Stub',
#  'Hambardzum Galstyan': 'Start',
#  'Gegham Gharibjanian': 'C',
#  'Gevorg Ghazaryan (politician)': 'Stub',
#  'Andrias Ghukasyan': 'Start',
#  'Aram Grigoryan': 'Stub',
#  'Armen Grigoryan (politician)': 'C',
#  'Hayk Grigoryan': 'Start',
#  'Grigor Jaghetyan': 'Stub',
#  'Tigran Karapetyan': 'Stub',
#  'Khachatur-Bek of Mush': 'Stub',
#  'Aram Kocharyan': 'Stub',
#  'Davit Lokyan': 'Start',
#  'Hrant Maloyan': 'C',
#  'Khachatur Malumian': 'Start',
#  'Aram Manukyan': 'Start',
#  'Gevorg Melik-Karagyozyan': 'Stub',
#  'Vahan Minakhoryan': 'Stub',
#  'Ruben Mirzakhanyan': 'Start',
#  'Badal Muradyan': 'Start',
#  'Gabriel Noradunkyan': 'C',
#  'Suren Papikyan': 'Start',
#  'Paul Paul': 'Start',
#  'Garo Paylan': 'C',
#  'Genrikh Poghosyan': 'Start',
#  'Ishkhan Saghatelyan': 'GA',
#  'Martiros Sarukhanyan': 'Stub',
#  'Vartkes Serengülian': 'Start',
#  'Serop Zakaryan': 'Stub',
#  'Servitchen': 'Stub',
#  'Suren Shadunts': 'Start',
#  'Kasbar Sinabian': 'Stub',
#  'Ohannes Tchekidjian': 'Start',
#  'Hrayr Tovmasyan': 'Stub',
#  'Usuv Beg': 'Stub',
#  'Kegham Vanigian': 'Start',
#  'Artak Zeynalyan': 'Start',
#  'Alfons Adam': 'Start',
#  'Ingo Appelt': 'Stub',
#  'Baron Alexander von Bach': 'C',
#  'Maximilian Anton Karl, Count Baillet de Latour': 'Start',
#  'Heinrich Alfred Barb': 'Start',
#  'Raphael Basch': 'Start',
#  'Leopold Berchtold': 'C',
#  'Hanns Blaschke': 'Stub',
#  'Andreas Bolek': 'Start',
#  'Joseph Buttinger': 'Start',
#  'Prince Carl of Solms-Braunfels': 'C',
#  'Count Wenzel Chotek of Chotkow and Wognin': 'Start',
#  "Citizens' Ministry": 'C',
#  'Richard von Coudenhove-Kalergi': 'C',
#  'Karl von Czyhlarz': 'Stub',
#  'George Abraham von Dyhrn': 'Stub',
#  'Hans Ferlitsch': 'Stub',
#  'Friedhelm Frischenschlager': 'Start',
#  'Anton Füster': 'Start',
#  'Julius Anton Glaser': 'C',
#  'Walter Guggenberger': 'Start',
#  'Ulrich Habsburg-Lothringen': 'Stub',
#  'Ernst Hampel (politician)': 'Stub',
#  'Franz von Hartig': 'Stub',
#  'Hans Peter Haselsteiner': 'Start',
#  'Friedrich Wilhelm von Haugwitz': 'C',
#  'Eduard Hedvicek': 'Stub',
#  'Eduard Herbst': 'Start',
#  'Hermann Stern': 'C',
#  'Jürgen Himmelbauer': 'Stub',
#  'Anton Hofer': 'Start',
#  'Andreas Hörtnagl': 'Stub',
#  'Franz Jetzinger': 'Start',
#  'Konstantin Jireček': 'C',
#  'Hugo Jury': 'C',
#  'Maximilian Ulrich von Kaunitz': 'Start',
#  'Joseph Kenner': 'Start',
#  'Theodor Kery': 'Stub',
#  'Michael Killisch-Horn': 'Stub',
#  'Hubert Klausner': 'Start',
#  'Martin Kocher': 'Stub',
#  'Józef Kożdoń': 'C',
#  'Jožef Krajnc': 'Start',
#  'Hans Kudlich': 'Start',
#  'Gottfried von Kühnelt-Leddihn': 'Start',
#  'Hartmann Lauterbacher': 'C',
#  'Otto Lecher': 'Stub',
#  'Franz Leitner (politician)': 'Stub',
#  'Elmar Lichtenegger': 'Start',
#  'Julius Lippert (historian)': 'Stub',
#  'Karl Lütgendorf': 'Stub',
#  'Jürgen Mandl': 'Stub',
#  'Renate Mann': 'Stub',
#  'Ferdinand Mannlicher': 'C',
#  'Christoph Matznetter': 'Start',
#  'Johann Gregor Memhardt': 'Stub',
#  'Franz Moroder': 'Start',
#  'Heinz Nittel': 'Stub',
#  'Brigitta Pallauf': 'Start',
#  'Wladimir von Pawlowski': 'Stub',
#  'Johann Anton von Pergen': 'C',
#  'Gerhard Pfanzelter': 'Start',
#  'Walter Pfrimer': 'B',
#  'Ernst von Plener': 'Start',
#  'Leopold Poetsch': 'Stub',
#  'Thomas Prinzhorn': 'C',
#  'Hermann von Ramberg': 'Stub',
#  'Heinrich Reschauer': 'Start',
#  'Horst Rosenkranz': 'Start',
#  'Emil Sax': 'Start',
#  'Karl Schmitzer': 'Stub',
#  'Georg Ritter von Schönerer': 'C',
#  'Georg Adam, Prince of Starhemberg': 'C',
#  'Gundaker Thomas Starhemberg': 'Start',
#  'Josef Staribacher': 'Stub',
#  'Richard Steidle': 'C',
#  'Julius Tandler': 'Start',
#  'Leopold, Count von Thun und Hohenstein': 'C',
#  'Muzio Tommasini': 'Start',
#  'Karl Freiherr von Vogelsang': 'Start',
#  'Max Winter (politician)': 'Stub',
#  'Anton von Winzor': 'Stub',
#  'Gisela Wurm': 'Stub',
#  'Alexander Zach': 'Stub',
#  'Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau': 'Start',
#  'Karl von Zinzendorf': 'Start',
#  'Muzamil Abdullayev': 'Stub',
#  'Leyla Abdullayeva': 'Start',
#  'Elchin Afandiyev': 'Start',
#  'Fazail Agamali': 'C',
#  'Fuad Alasgarov': 'C',
#  'Anvar Alikhanov': 'Stub',
#  'Tarlan Aliyarbayov': 'GA',
#  'Dilara Aliyeva': 'Start',
#  'Ali Asadov': 'Start',
#  'Akram Aylisli': 'C',
#  'Sahil Babayev': 'Start',
#  'Huseyngulu Baghirov': 'Start',
#  'Alovsat Bakhshiyev': 'Start',
#  'Rafael Kamil Dzhabrailov': 'Stub',
#  'Matin Eynullayev': 'Start',
#  'Vilayat Eyvazov': 'Start',
#  'Abdurrahman Fatalibeyli': 'C',
#  'Fazail Ibrahimli': 'Stub',
#  'Solomon Grobshtein': 'Stub',
#  'Teymur Guliyev': 'Stub',
#  'Mammad Gurbanov': 'Start',
#  'Asaf Hajiyev': 'C',
#  'Farhad Hajiyev': 'Start',
#  'Jamil Hasanli': 'C',
#  'Ali M. Hasanov': 'C',
#  'Shakir Hasanov': 'Stub',
#  'Zakir Hasanov': 'C',
#  'Ali Huseynli': 'Start',
#  'Alisahib Huseynov': 'Start',
#  'Ali Ibrahimov': 'Stub',
#  'Mammad Isgandarov': 'Stub',
#  'Vidadi Isgandarov': 'Start',
#  'Ajdar Ismailov': 'C',
#  'Saftar Jafarov': 'Start',
#  'Rovshan Javadov': 'C',
#  'Anar Karimov': 'Start',
#  'Boris Kevorkov': 'Start',
#  'Gurban Khalilov': 'Start',
#  'Ahmad Kordary': 'Stub',
#  'Ilham Madatov': 'Start',
#  'Musa Mammadov': 'Start',
#  'Ramin Mammadov': 'Start',
#  'Elshad Mirbashir oghlu': 'C',
#  'Fuad Naghiyev': 'Start',
#  'Eldar Namazov': 'Start',
#  'Siyavush Novruzov': 'Start',
#  'Sadig Rahimov': 'C',
#  'Suleyman Rahimov': 'C',
#  'Huseyn Rahmanov': 'Stub',
#  'Hasan Sayidov': 'Stub',
#  'Parviz Shahbazov': 'Start',
#  'Mammad agha Shahtakhtinski': 'C',
#  'Abid Sharifov': 'Start',
#  'Bakhtiyar Vahabzadeh': 'C',
#  'Elmir Valiyev': 'Start',
#  'Nurali Yusifbayli': 'Start',
#  'Harold Christie': 'Start',
#  'Timothy Donaldson': 'C',
#  'Joseph Robert Love': 'C',
#  'Mohammed Isa Al Abbasi': 'Stub',
#  'Abdullah bin Isa Al Khalifa': 'Stub',
#  'Ahmed Behzad (Bahrain)': 'Stub',
#  'Kamal Ahmed (politician)': 'Stub',
#  'Mohamed Ali Hasan Ali': 'Stub',
#  'Khalid Almoayed': 'Stub',
#  'Aymen Tawfeeq Almoayed': 'Start',
#  'Nazar Al Baharna': 'Start',
#  'Mahmood Al Bahrani': 'Stub',
#  'Ammar Al Bannai': 'Start',
#  'Jawad Fairooz': 'Start',
#  'Qasim Fakhro': 'Start',
#  'Faisal al-Hamar': 'Stub',
#  'Nabeel bin Yaqub Al-Hamar': 'Stub',
#  'Isa bin Abdulrahman Al Hammadi': 'Stub',
#  'Jameel Humadan': 'Start',
#  'Isa bin Ibrahim Al Khalifa': 'Stub',
#  'Fahmi al-Jowder': 'Stub',
#  'Saud Kanoo': 'Stub',
#  'Essam Khalaf': 'Stub',
#  'Abdullah bin Hamad bin Isa Al Khalifa': 'Start',
#  'Ibrahim ibn Khalifa Al Khalifa': 'Start',
#  'Mai bint Mohammed Al Khalifa': 'Start',
#  'Khallfa bin Duaij Al Khalifa': 'Stub',
#  'Hamad Al Kooheji': 'Stub',
#  'Abdullatif Al-Mahmood': 'Stub',
#  'Khalid Al Maskati': 'Stub',
#  'Abdulhussain bin Ali Mirza': 'Stub',
#  'Mohammed Al-Buainain': 'Start',
#  'Mohammed bin Khalifa bin Ahmed': 'C',
#  'Mohammed bin Khalifa bin Ali Al Khalifa': 'Start',
#  'Abdulrahman al-Nuaimi': 'Start',
#  'Ammar Qambar': 'Start',
#  'Isa Qassim': 'C',
#  'Ahmed Al-Salloum': 'Start',
#  'Salman bin Hamad Al Khalifa': 'C',
#  'Oli Ahad': 'Start',
#  'Farid Ahmed': 'Stub',
#  'Muzaffar Ahmed (NAP politician)': 'Start',
#  'AKM Hafizuddin': 'Start',
#  'Mohammad Manjur Alam': 'Start',
#  'Aftab Ali': 'C',
#  'M Hossain Ali': 'Start',
#  'Ashab Uddin Ahmad': 'B',
#  'Selina Banu': 'Start',
#  'Nurul Huq Bhuiyan': 'Stub',
#  'Bishnu Chattopadhyay': 'Start',
#  'AKM Fazlul Kabir Chowdhury': 'Start',
#  'Aminul Islam Chowdhury': 'Stub',
#  'Anwarul Karim Chowdhury': 'C',
#  'Moinuddin Ahmed Chowdhury': 'C',
#  'Sarwar Jan Chowdhury': 'Stub',
#  'Shahinur Pasha Chowdhury': 'Start',
#  'Yusuf Ali Chowdhury': 'Start',
#  'Haji Mohammad Danesh': 'C',
#  'Pulin De': 'Start',
#  'James Leo Ferguson': 'C',
#  'Abdul Halim Ghaznavi': 'Start',
#  'Debendra Nath Ghosh': 'Stub',
#  'Ranesh Das Gupta': 'Start',
#  'AKM Fazlul Haque (Bangladeshi politician)': 'Stub',
#  'Abul Hashim': 'C',
#  'Syed Najmuddin Hashim': 'Start',
#  'M. Anwar Hossain': 'C',
#  'Nozir Hossain': 'Start',
#  'Syed Muhammad Ibrahim': 'Start',
#  'Abul Kashem': 'C',
#  'Abul Kashem Khan': 'C',
#  'Hatem Ali Khan': 'Start',
#  'Muhammad Hamidullah Khan': 'C',
#  'Yar Mohammad Khan': 'C',
#  'Jyotirindra Bodhipriya Larma': 'Stub',
#  'Manik Lal Ray': 'Stub',
#  'Mushrefa Mishu': 'Start',
#  'Fazlul Haque Montu': 'Stub',
#  'Mujahidul Islam Selim': 'Stub',
#  'SM Nuruzzaman': 'Stub',
#  'Shamsul Huda Panchbagi': 'B',
#  'Muhammad Bayazeed Khan Panni': 'C',
#  'Ferdous Ahmed Qureshi': 'Start',
#  'Abdur Rahim (scholar)': 'C',
#  'Habibar Rahman': 'Stub',
#  'M. M. Rahmatullah': 'C',
#  'Golam Maula Rony': 'Start',
#  'Devasish Roy': 'Start',
#  'Maulana Shakhawat': 'Stub',
#  'Zahidunnabi Dewan Shamim': 'Start',
#  'Abul Kalam Shamsuddin': 'Start',
#  'Badruddoza Ahmed Shuja': 'Stub',
#  'Mohammad Sultan': 'Start',
#  'Mohammad Toaha': 'Start',
#  'Badruddin Umar': 'C',
#  'Elliott Belgrave': 'Start',
#  'Chad Blackman': 'Start',
#  'Santia Bradshaw': 'Start',
#  'Sonia Browne': 'Stub',
#  'Michael A. Carrington': 'Start',
#  'William Fondleroy Duguid': 'Start',
#  'Reginald Farley': 'Stub',
#  'Adrian Forde': 'Stub',
#  'Cynthia Y. Forde': 'Start',
#  'Ian Gooding-Edghill': 'Stub',
#  'Damien K. A. Griffith': 'Stub',
#  'Crystal Haynes': 'Stub',
#  'Hallam Henry (diplomat)': 'Stub',
#  'Philip St. Hill': 'Stub',
#  'Arthur Holder': 'Stub',
#  'Kirk Matthew Humphrey': 'Stub',
#  'Davidson Ishmael': 'Stub',
#  'Colin Everett Jordan': 'Stub',
#  'John Andrew King': 'Start',
#  'Shantal Munro-Knight': 'Stub',
#  'Glyne Murray': 'Stub',
#  'Harry Scott Newlands': 'Stub',
#  "Charles Duncan O'Neal": 'Start',
#  'Samuel Jackman Prescod': 'C',
#  'Shanika Roberts-Odle': 'Stub',
#  'Ryan Straughan': 'Stub',
#  'Dwight Sutherland': 'Stub',
#  'Kerrie Symmonds': 'Start',
#  'Yury Ambrazevich': 'Stub',
#  'Lyavon Barshchewski': 'Stub',
#  'Siarhei Cherachen': 'Start',
#  'Zmitser Dashkevich': 'Start',
#  'Siamion Domash': 'Stub',
#  'Tsimafei Dranchuk': 'Start',
#  'Alaksandar Dubko': 'Stub',
#  'Alana Gebremariam': 'Start',
#  'Gennady Grushevoy': 'C',
#  'Moshe Gutman': 'Stub',
#  'Uładzimir Hančaryk': 'Stub',
#  'Tamaš Hryb': 'C',
#  'Anatoĺ Kalinin': 'Start',
#  'Uładzisłau Kazłouski': 'Start',
#  'Pavel Pavlovich Kozlovsky': 'C',
#  'Ivan Kubrakov': 'Start',
#  'Vladimir Kumets': 'C',
#  'Vyacheslav Nikolayevich Kuznetsov': 'Stub',
#  'Valery Levaneuski': 'C',
#  'Pavel Liohki': 'Start',
#  'Uladzimir Mackievič': 'C',
#  'Vladimir Parfenovich': 'Start',
#  'Jan Pazniak': 'Stub',
#  'Aleksandr Potupa': 'C',
#  'Pyotr Prakapovich': 'Stub',
#  'Alexander Radkov': 'Start',
#  'Symon Rak-Michajłoŭski': 'GA',
#  'Vladimir Vasilievich Rusakevich': 'Start',
#  'Ihar Rynkevich': 'C',
#  'Aliaksandr Shakutsin': 'C',
#  'Nikolai Shelyagovich': 'Start',
#  'Jan Stankievič': 'Start',
#  'Mikola Statkevich': 'C',
#  'Sergei Tikhanovsky': 'C',
#  'Alaksandar Ćvikievič': 'C',
#  'Aleksandr Turchin': 'Stub',
#  'Franak Viačorka': 'C',
#  'Yury Voskresensky': 'C',
#  'Ivan Yermachenka': 'Start',
#  'Manuel Abramowicz': 'Stub',
#  'Rudy Aernoudt': 'C',
#  'Herman Baltia': 'Start',
#  'Jan Béghin': 'Start',
#  'Frank Beke': 'Stub',
#  'Gustave Boël': 'Start',
#  'Pol Clovis Boël': 'Start',
#  'Antoine Brun': 'Start',
#  'Fernand Cocq': 'Stub',
#  'Émile Coulonvaux': 'Stub',
#  'Auguste Couvreur': 'Stub',
#  'Nico Cué': 'Start',
#  'Pierre David (mayor)': 'GA',
#  'August De Boodt': 'Start',
#  'Dirk De fauw': 'Start',
#  'René De Feyter': 'Stub',
#  'François-Philippe de Haussy': 'Stub',
#  'Victor de Laveleye': 'Start',
#  'Édouard Descamps': 'Start',
#  'José Desmarets': 'Stub',
#  'Émile van Dievoet': 'C',
#  'Marc Drumaux': 'Start',
#  'Jos Dupré': 'Stub',
#  'Françoise Dupuis': 'Stub',
#  'Veerle Geerinckx': 'Start',
#  "Eugène Goblet d'Alviella": 'Start',
#  'Jean-Pierre Grafé': 'Stub',
#  'Jacques Grippa': 'Stub',
#  'Guy Hance': 'Stub',
#  'Joris Helleputte': 'Start',
#  'Lucienne Herman-Michielsens': 'Start',
#  'Jules Hiernaux': 'Stub',
#  'Julius Hoste Jr.': 'Start',
#  'Norbert Hougardy': 'Stub',
#  'Joseph Houssa': 'Stub',
#  'Vincent Houssiau': 'Start',
#  'Pierre Van Humbeeck': 'Stub',
#  'Dorah Ilunga': 'Start',
#  'Pierre Imperiali': 'Stub',
#  'Jean-François Istasse': 'Stub',
#  'Milou Jeunehomme': 'Stub',
#  'André Kempinaire': 'Stub',
#  'Willy Kuijpers': 'Stub',
#  'Rachid Madrane': 'Start',
#  'Luc Michel': 'Start',
#  'Fientje Moerman': 'Start',
#  'André Molitor': 'Start',
#  'Jean Pede': 'Start',
#  'Jean-Marie Piret': 'Start',
#  'André-Eugène Pirson': 'Start',
#  "Philippe-Ambroise d'Olmen, Baron de Poederlé": 'Stub',
#  'Marjet Van Puymbroeck': 'Stub',
#  'Jean Richardot the Younger': 'Start',
#  'Gustave Rolin-Jaequemyns': 'C',
#  'Hippolyte Rolin': 'Stub',
#  'Father Samuel': 'Start',
#  'Louis-Joseph Seutin': 'Start',
#  'Alfons Siffer': 'Start',
#  'Cyrille Tahay': 'Stub',
#  'Jacques Timmermans': 'Stub',
#  'Robert Urbain': 'Stub',
#  'Jacques Van Gompel': 'Start',
#  'Marcel Van Langenhove (referee)': 'Stub',
#  'Johan Verbeke': 'Start',
#  'Lodewijk Verreycken': 'Start',
#  'Louis Waltniel': 'Stub',
#  'Yves de Wasseige': 'Start',
#  'Jacques van Ypersele de Strihou': 'C',
#  'Beverly Castillo': 'Stub',
#  'Elfreda Reyes': 'C',
#  'Bert Tucker': 'C',
#  'Michel Ahouanmènou': 'Start',
#  'Arnauld Antoine Akodjènou': 'C',
#  'Jules-Armand Aniambossou': 'Start',
#  'Pascal Chabi Kao': 'Start',
#  'Francis Covi': 'Stub',
#  'Joachim Dahissiho': 'Stub',
#  'Adrien Degbey': 'C',
#  'Luc Gnacadja': 'C',
#  'Paul Hazoumé': 'Start',
#  'Louis Hunkanrin': 'C',
#  'Louis Ignacio-Pinto': 'Stub',
#  'Arouna Mama': 'Start',
#  'Moussa Okanla': 'Start',
#  'Assogba Oké': 'Start',
#  'Émile Poisson': 'Stub',
#  'Maximilien Quenum-Possy-Berry': 'Start',
#  'Nicéphore Soglo': 'GA',
#  'Dorjee Wangmo': 'Stub',
#  'Ugyen Dorji (DNT politician)': 'Start',
#  'Zangley Dukpa': 'Stub',
#  'Dupthob': 'Stub',
#  'Pema Gyamtsho': 'Start',
#  'Choki Gyeltshen': 'Stub',
#  'Sherub Gyeltshen': 'Start',
#  'Choida Jamtsho': 'Start',
#  'Rinzin Jamtsho': 'Stub',
#  'Kunzang C. Namgyel': 'Start',
#  'Shingkhar Lam': 'Start',
#  'Tshewang Lhamo': 'Start',
#  'Kuenga Loday': 'Stub',
#  'Dorji Namgyal': 'Stub',
#  'Jigme Namgyal (Bhutan)': 'C',
#  'Wangdi Norbu': 'Stub',
#  'Kinga Penjor': 'Stub',
#  'Yeshey Penjor': 'Start',
#  'Thakur S. Powdyel': 'C',
#  'Jai Bir Rai': 'Start',
#  'Karma Rangdol': 'Stub',
#  'Loknath Sharma': 'Start',
#  'Tenzin (politician)': 'Stub',
#  'Sonam Tobgye': 'Start',
#  'Dorji Tshering': 'Start',
#  'Kinga Tshering': 'Start',
#  'Namgay Tshering': 'Start',
#  'Ugyen Tshering': 'Stub',
#  'Jigme Wangchuk': 'Stub',
#  'Lhatu Wangchuk': 'Stub',
#  'Khandu Wangchuk': 'Start',
#  'Norbu Wangchuk': 'Stub',
#  'Tshering Wangchuk': 'Start',
#  'Karma Donnen Wangdi': 'Start',
#  'Tshencho Wangdi': 'Start',
#  'Ugyen Wangdi': 'Stub',
#  'Dechen Wangmo (politician)': 'Start',
#  'Dechen Zangmo': 'Stub',
#  'Neten Zangmo': 'Start',
#  'Nidup Zangpo': 'Stub',
#  'Yeshey Zimba': 'Start',
#  'Nataniel Aguirre': 'C',
#  'Jacobo Aillón': 'Start',
#  'Isaac Ávalos': 'Stub',
#  'Augusto Céspedes': 'Start',
#  'Soledad Chapetón': 'Start',
#  'Adolfo Chávez': 'Stub',
#  'Chi Hyun Chung': 'C',
#  'Daniel Sánchez Bustamante': 'GA',
#  'Rafael Peña': 'Start',
#  'Marcial Fabricano': 'Start',
#  'Francisco Argandoña': 'Start',
#  'Antonio Machaca': 'Stub',
#  'Adolfo Mendoza': 'Stub',
#  'Pedro Domingo Murillo': 'Start',
#  "Francisco Burdett O'Connor": 'GA',
#  'Manuel Luis de Oliden': 'Stub',
#  'Isabel Ortega Ventura': 'Stub',
#  'Simón Iturri Patiño': 'C',
#  'Bonifacio Pinedo': 'Stub',
#  'Julio Pinedo': 'Stub',
#  'José Mariano Serrano': 'Stub',
#  'Moisés Torres (politician)': 'Start',
#  'Fernando Vargas Mosua': 'Start',
#  'Jaime de Zudáñez': 'Stub',
#  'Elvira Abdić-Jelenović': 'Stub',
#  'Mehmed Alajbegović': 'C',
#  'Boško Baškot': 'Stub',
#  'Hasan Brkić': 'C',
#  'Salko Bukvarević': 'Start',
#  'Mirsad Ćeman': 'Start',
#  'Selmo Cikotić': 'C',
#  'Sabina Ćudić': 'Stub',
#  'Milorad Dodik': 'B',
#  'Dženan Đonlagić': 'Start',
#  'Nijaz Duraković': 'Start',
#  'Edin Forto': 'Start',
#  'Dževad Galijašević': 'C',
#  'Josip Grubeša': 'Start',
#  'Ankica Gudeljević': 'Start',
#  'Muhamed Hadžijamaković': 'Stub',
#  'Mirsad Hadžikadić': 'Start',
#  'Sanjin Halimović': 'Start',
#  'Husein Miljković': 'GA',
#  'Jasmin Imamović': 'Stub',
#  'Alija Izetbegović': 'C',
#  'Adamir Jerković': 'GA',
#  'Esed Kadrić': 'Stub',
#  'Mehmed Kapetanović': 'Start',
#  'Salmir Kaplan': 'Stub',
#  'Osman Karabegović': 'C',
#  'Fuad Kasumović': 'GA',
#  'Rudi Kolak': 'Start',
#  'Ivo Komšić': 'C',
#  'Rusmir Mahmutćehajić': 'Start',
#  'Ante Marković': 'C',
#  'Amor Mašović': 'Start',
#  'Dragan Mektić': 'Start',
#  'Ademaga Mešić': 'C',
#  'Jelka Miličević': 'Start',
#  'Abdulah Mutapčić': 'Stub',
#  'Abdulah Nakaš': 'Start',
#  'Mario Nenadić': 'Start',
#  'Damir Nikšić': 'GA',
#  'Ismet Popovac': 'FA',
#  'Hakija Pozderac': 'Start',
#  'Hamdija Pozderac': 'C',
#  'Nurija Pozderac': 'Start',
#  'Đuro Pucar': 'C',
#  'Fahrudin Radončić': 'C',
#  'Alen Šeranić': 'Start',
#  'Uglješa Uzelac': 'Start',
#  'Nezir Škaljić': 'C',
#  'Ibrahim Spahić': 'Start',
#  'Emir Suljagić': 'C',
#  'Svetozar Pudarić': 'Start',
#  'Miloš Vukašinović': 'Start',
#  'Daniel Kwele': 'Stub',
#  'Michael Dingake': 'Stub',
#  'James G. Haskins': 'Stub',
#  'Tshenolo Mabeo': 'Stub',
#  'Philip Matante': 'Stub',
#  'Gomolemo Motswaledi': 'Start',
#  'Motsamai Mpho': 'Stub',
#  'Sylvia Muzila': 'Start',
#  'Leetile Disang Raditladi': 'Start',
#  'Benjamin Thema': 'Stub',
#  'Patrick van Rensburg': 'Start',
#  'Maria de Lourdes Abadia': 'Stub',
#  'José de Abreu (politician)': 'Stub',
#  'Rafael Tobias de Aguiar': 'Stub',
#  'Medeiros e Albuquerque': 'Start',
#  'Léo de Almeida Neves': 'Stub',
#  'Simão Almeida': 'Stub',
#  'Antônio Pinto Chichorro da Gama': 'Stub',
#  'Cipriano Barata': 'Start',
#  'Irani Barbosa': 'Stub',
#  'Jaison Barreto': 'Stub',
#  'Djalma Bastos de Morais': 'Stub',
#  'Henrique de Beaurepaire-Rohan, Viscount of Beaurepaire-Rohan': 'Stub',
#  'José Paulo Bisol': 'Start',
#  'Natália Bastos Bonavides': 'Stub',
#  'João Francisco Inácio Brazão': 'Stub',
#  'Amador Bueno': 'Start',
#  'Antônio Câmara': 'Stub',
#  'Luiz Humberto Carneiro': 'Start',
#  'Izolda Cela': 'C',
#  'Margarete Coelho': 'Stub',
#  'Ivandro Cunha Lima': 'Stub',
#  'João Cunha (politician)': 'Stub',
#  'Aécio de Borba': 'Stub',
#  'José Abílio Silva de Santana': 'Stub',
#  'Alércio Dias': 'Stub',
#  'Délio dos Santos': 'Stub',
#  'Ademar Frederico Duwe': 'Stub',
#  'Elcione Zahluth Barbalho': 'Stub',
#  "Gastão d'Escragnolle, Baron d'Escragnolle": 'Stub',
#  'Paulo Cesar Farias': 'Start',
#  'Emília Fernandes': 'Start',
#  'José Carlos da Silva Mayrink Ferrão': 'Start',
#  'Dalva Figueiredo': 'Stub',
#  'Francisco Julião': 'Stub',
#  'Jofran Frejat': 'Stub',
#  'Edmundo Galdino': 'Stub',
#  'Joaquim Gomes de Souza': 'Start',
#  'Abdul Hamid Sebba': 'Stub',
#  'Jutahy Júnior': 'Stub',
#  'Joaquim Gonçalves Ledo': 'C',
#  'Antônio Leite Andrade': 'Stub',
#  'Alceste Madeira': 'Stub',
#  'Beto Mansur': 'Stub',
#  'Horácio de Matos': 'Stub',
#  'Sandra Meira Starling': 'Stub',
#  'Gerardo Melo Mourão': 'Start',
#  'Guilherme Melo (politician)': 'Start',
#  'Murilo Melo Filho': 'Stub',
#  'Cândido Mendes de Almeida': 'Start',
#  'Gilmar Mendes': 'C',
#  'Edmur Mesquita': 'Stub',
#  'Miguel Couto': 'Start',
#  'Claudio Modesto': 'Start',
#  'Armando Monteiro (politician)': 'Stub',
#  'Carlos Eduardo Moreira Ferreira': 'Stub',
#  'Pedro Soares Muñoz': 'Stub',
#  'Dora Nascimento': 'Stub',
#  'Carlos Neder': 'Stub',
#  'Domingos Gomes de Aguiar Neto': 'Start',
#  'Manuel Luís Osório, Marquis of Erval': 'C',
#  'Hildebrando Pascoal': 'Start',
#  'Astrojildo Pereira': 'Stub',
#  'Joaquim Alvaro Pereira Leite': 'Stub',
#  'Jorge Picciani': 'Start',
#  'Francisco José Pinheiro': 'Start',
#  'Mario Pinotti': 'C',
#  'Henrique Pizzolato': 'Start',
#  'Plínio de Arruda Sampaio Jr.': 'C',
#  'Irondi Pugliesi': 'Stub',
#  'Eusébio de Queirós': 'C',
#  'Ratinho (TV presenter)': 'Start',
#  'Marco Antonio Raupp': 'Start',
#  'Robert Rey (plastic surgeon)': 'C',
#  'Ary Rigo': 'Stub',
#  'Antônio Ricardo dos Santos': 'Start',
#  'Euclides Scalco': 'Stub',
#  ...}

# %%
ARTICLE_SCORES_NULL
# Out:
# []

# %% [markdown]
# We observe that all articles had a score!

# %% [markdown]
# # Step 3: Combining the Datasets

# %% [markdown]
# We first convert the previous article quality prediction result into a DataFrame in order to handle it better

# %%
article_quality_df = pd.DataFrame(list(ARTICLE_SCORES.items()),columns = ['name','article_quality'])
revision_id_df = pd.DataFrame(list(ARTICLE_REVISIONS.items()),columns = ['name','revision_id'])

# %% [markdown]
# We assign a region to each country in the country list (**Referenced in step 4**)

# %%
def populate_region(row):
    if row['Geography'].isupper():
        return row['Geography']
    else:
        return None
population['region'] = population.apply(populate_region,axis=1)
population.ffill(inplace=True)

# %% [markdown]
# We obtain the following region populated table

# %%
population
# Out:
#            Geography  Population (millions)           region
# 0              WORLD                 7963.0            WORLD
# 1             AFRICA                 1419.0           AFRICA
# 2    NORTHERN AFRICA                  251.0  NORTHERN AFRICA
# 3            Algeria                   44.9  NORTHERN AFRICA
# 4              Egypt                  103.5  NORTHERN AFRICA
# ..               ...                    ...              ...
# 228            Samoa                    0.2          OCEANIA
# 229  Solomon Islands                    0.7          OCEANIA
# 230            Tonga                    0.1          OCEANIA
# 231           Tuvalu                    0.0          OCEANIA
# 232          Vanuatu                    0.3          OCEANIA
#
# [233 rows x 3 columns]

# %% [markdown]
# We now can merge the tables to obtain the desired final table and save the final table in a CSV file

# %%
#We first merge with politicians to have the country of each politician
article_quality_country_df = article_quality_df.merge(politicians[['name','country']], left_on='name', right_on='name')
#We merge with population to have the associated population size of the politicians country
wp_politicians_by_country = article_quality_country_df.merge(population, left_on='country', right_on='Geography').drop(columns='Geography')
#We merge with the revision_id_df to associate the revision_id for each article in the table
wp_politicians_by_country = wp_politicians_by_country.merge(revision_id_df, left_on='name', right_on='name')
#We rename to have standard names in our table
wp_politicians_by_country = wp_politicians_by_country.rename({'Population (millions)':'population','name':'article_title'})
#We save the final table to CSV format
wp_politicians_by_country.to_csv('../results/wp_politicians_by_country.csv', index=False)

# %% [markdown]
# We notice that there are countries for which there are no matches, we separate these into a separate list that we save as a txt in '../results/wp_countries-no_match.txt'

# %%
#We create sets of countries in politicians and in populations that we will compare later
politicians_country_set = set(article_quality_country_df.country)
population_country_set = set(population.Geography)
#We create the lists where we will store the results
match = []
population_not_in_politicians = []
politicians_not_in_population = []
for country in population_country_set:
    if country in politicians_country_set:
        #they matched so no problem
        match.append(country)
    else:
        #we enter the case where it is in the population but not in the politicians set.
        #we check if it is a region
        if country.isupper():
            #not a country so we don't append
            continue
        else:
            population_not_in_politicians.append(country)
#we now check for the other case, namely, when it is in politicians but not in population set
for country in politicians_country_set:
    if country in population_country_set:
        continue
    else:
        politicians_not_in_population.append(country)

#We join the two lists to have a single file with all the mismatches
wp_countries_no_match = population_not_in_politicians + politicians_not_in_population
with open('../results/wp_countries-no_match.txt', 'w') as f:
    for country in wp_countries_no_match:
        f.write(country)
        f.write('\n')

# %% [markdown]
# We notice that the politicians data source does not contain multiple important countries such as USA, Canada, UK, New Zeland, Austalia, Phillipines, etc. It also lacks some data for smaller countries such as New Caledonia, Puerto Rico, French Polynesia, etc.
#
# We notice that in the politicians data source there is a record that does not appear in population: 'Korean'. Investigating further into case-by-case articles, we observe that most of these Korean politicians are from older eras when Korea was one whole country, given that we have representation of the newer South and North Korea and that we do not have the population of what was once Korea

# %% [markdown]
# # Step 4: Analysis

# %% [markdown]
# In this analysis a country can only exist in one region. The population_by_country_2022.csv actually represents regions in a hierarchical order. For your analysis always put a country in the closest (lowest in the hierarchy) region.
# **This has already been done before in Step 3**

# %% [markdown]
# For this analysis you should consider "high quality" articles to be articles that ORES predicted would be in either the "FA" (featured article) or "GA" (good article) classes. So we create a function and apply it to the 'article_quality' column in order to obtain this dichotomus variable

# %%
def populate_high_quality(row):
    if row['article_quality'] in ['FA', 'GA']:
        return 1
    else:
        return 0
wp_politicians_by_country['high_quality'] = wp_politicians_by_country.apply(populate_high_quality,axis=1)
wp_politicians_by_country
# Out:
#                        name article_quality      country  \
# 0           Shahjahan Noori              GA  Afghanistan
# 1     Abdul Ghafar Lakanwal           Start  Afghanistan
# 2            Majah Ha Adrif           Start  Afghanistan
# 3         Haroon al-Afghani               B  Afghanistan
# 4               Tayyab Agha           Start  Afghanistan
# ...                     ...             ...          ...
# 7501        Rekayi Tangwena            Stub     Zimbabwe
# 7502       Josiah Tongogara               C     Zimbabwe
# 7503      Langton Towungana            Stub     Zimbabwe
# 7504    Herbert Ushewokunze            Stub     Zimbabwe
# 7505           Denis Walker               C     Zimbabwe
#
#       Population (millions)          region  revision_id  high_quality
# 0                      41.1      SOUTH ASIA   1099689043             1
# 1                      41.1      SOUTH ASIA    943562276             0
# 2                      41.1      SOUTH ASIA    852404094             0
# 3                      41.1      SOUTH ASIA   1095102390             0
# 4                      41.1      SOUTH ASIA   1104998382             0
# ...                     ...             ...          ...           ...
# 7501                   16.3  EASTERN AFRICA   1073818982             0
# 7502                   16.3  EASTERN AFRICA   1106932400             0
# 7503                   16.3  EASTERN AFRICA    904246837             0
# 7504                   16.3  EASTERN AFRICA    959111842             0
# 7505                   16.3  EASTERN AFRICA   1111257734             0
#
# [7506 rows x 7 columns]

# %%
wp_politicians_by_country[wp_politicians_by_country['Population (millions)'] == 0.0]
# Out:
#                             name article_quality        country  \
# 5265                 Alfons Goop            Stub  Liechtenstein
# 5266    Peter Kaiser (historian)           Start  Liechtenstein
# 5635       Jean-Charles Allavena            Stub         Monaco
# 5636             Laurent Anselmi            Stub         Monaco
# 5637               Camille Blanc           Start         Monaco
# 5638             Robert Calcagno               C         Monaco
# 5639             Jean Castellini            Stub         Monaco
# 5640   Paul Demange (politician)            Stub         Monaco
# 5641          Catherine Fautrier            Stub         Monaco
# 5642               Paul Masseron           Start         Monaco
# 5643             Laurent Nouvion            Stub         Monaco
# 5644               Thierry Poyet            Stub         Monaco
# 5645      Jean-François Robillon           Start         Monaco
# 5646          Christophe Steiner            Stub         Monaco
# 5647              Gilles Tonelli               B         Monaco
# 5854            Bernard Dowiyogo           Start          Nauru
# 5855             Valdon Dowiyogo           Start          Nauru
# 6238  Faustina K. Rehuher-Marugg           Start          Palau
# 6623               Pio Chiaruzzi            Stub     San Marino
# 6624          Alessandro Mancini            Stub     San Marino
# 7144               Teniku Talesi           Start         Tuvalu
# 7145            Ielemia Ministry           Start         Tuvalu
# 7146              Iakoba Italeli              GA         Tuvalu
# 7147               Lotoala Metia               C         Tuvalu
# 7148               Henry Naisali               C         Tuvalu
# 7149                Falesa Pitoi           Start         Tuvalu
# 7150       Second Toafa Ministry           Start         Tuvalu
# 7151               Taom Tanukale           Start         Tuvalu
# 7152             Telavi Ministry           Start         Tuvalu
# 7153         Fiatau Penitala Teo           Start         Tuvalu
# 7154                 Solofa Uota            Stub         Tuvalu
#
#       Population (millions)           region  revision_id  high_quality
# 5265                    0.0   WESTERN EUROPE   1030085950             0
# 5266                    0.0   WESTERN EUROPE   1086304418             0
# 5635                    0.0   WESTERN EUROPE   1003397193             0
# 5636                    0.0   WESTERN EUROPE   1115213350             0
# 5637                    0.0   WESTERN EUROPE   1100905415             0
# 5638                    0.0   WESTERN EUROPE   1030845142             0
# 5639                    0.0   WESTERN EUROPE   1084495128             0
# 5640                    0.0   WESTERN EUROPE   1079067018             0
# 5641                    0.0   WESTERN EUROPE   1106302712             0
# 5642                    0.0   WESTERN EUROPE   1089373743             0
# 5643                    0.0   WESTERN EUROPE   1011192042             0
# 5644                    0.0   WESTERN EUROPE    960140393             0
# 5645                    0.0   WESTERN EUROPE    986531700             0
# 5646                    0.0   WESTERN EUROPE   1113747641             0
# 5647                    0.0   WESTERN EUROPE   1114437692             0
# 5854                    0.0          OCEANIA   1109278952             0
# 5855                    0.0          OCEANIA   1115307502             0
# 6238                    0.0          OCEANIA   1113920085             0
# 6623                    0.0  SOUTHERN EUROPE   1102951189             0
# 6624                    0.0  SOUTHERN EUROPE   1109440451             0
# 7144                    0.0          OCEANIA   1105357928             0
# 7145                    0.0          OCEANIA   1110459840             0
# 7146                    0.0          OCEANIA   1112876425             1
# 7147                    0.0          OCEANIA   1048653554             0
# 7148                    0.0          OCEANIA   1067976437             0
# 7149                    0.0          OCEANIA   1069026585             0
# 7150                    0.0          OCEANIA   1110459929             0
# 7151                    0.0          OCEANIA   1048466076             0
# 7152                    0.0          OCEANIA   1110459962             0
# 7153                    0.0          OCEANIA   1069888129             0
# 7154                    0.0          OCEANIA    994787433             0

# %% [markdown]
# We observe that some populations are 0, this means that when we will do the division to find per_capita numbers, these will divide by 0 which we want to prevent, so we remove these countries from the analysis and results

# %%
wp_politicians_by_country = wp_politicians_by_country[wp_politicians_by_country['Population (millions)'] != 0.0]

# %% [markdown]
# # Step 5: Results

# %% [markdown]
# We first prepare our tables in order to easily obtain the results we want in Step 5

# %% [markdown]
# ## total-articles-per-population (a ratio representing the number of articles per person)

# %%
#Country-by-country
#We groupby country, counting the number of articles per country in column "number_of_articles"
count_by_country = wp_politicians_by_country.groupby('country').count()['name'].reset_index().rename({"name":"number_of_articles"}, axis=1)
#We merge with population table to obtain the population data for each country
total_articles_per_population_country = count_by_country.merge(population, how='left', left_on= 'country', right_on = 'Geography')
#We create a new column with the total_articles_per_population which is the division of number of articles by population. 
total_articles_per_population_country['total_articles_per_population'] = total_articles_per_population_country['number_of_articles']/total_articles_per_population_country['Population (millions)']
total_articles_per_population_country
# Out:
#          country  number_of_articles    Geography  Population (millions)  \
# 0    Afghanistan                 118  Afghanistan                   41.1
# 1        Albania                  83      Albania                    2.8
# 2        Algeria                  34      Algeria                   44.9
# 3        Andorra                  10      Andorra                    0.1
# 4         Angola                  42       Angola                   35.6
# ..           ...                 ...          ...                    ...
# 173    Venezuela                  62    Venezuela                   28.3
# 174      Vietnam                  27      Vietnam                   99.4
# 175        Yemen                  61        Yemen                   33.7
# 176       Zambia                  13       Zambia                   20.0
# 177     Zimbabwe                  63     Zimbabwe                   16.3
#
#               region  total_articles_per_population
# 0         SOUTH ASIA                       2.871046
# 1    SOUTHERN EUROPE                      29.642857
# 2    NORTHERN AFRICA                       0.757238
# 3    SOUTHERN EUROPE                     100.000000
# 4      MIDDLE AFRICA                       1.179775
# ..               ...                            ...
# 173    SOUTH AMERICA                       2.190813
# 174   SOUTHEAST ASIA                       0.271630
# 175     WESTERN ASIA                       1.810089
# 176   EASTERN AFRICA                       0.650000
# 177   EASTERN AFRICA                       3.865031
#
# [178 rows x 6 columns]

# %%
#Regional
#We groupby region, counting the number of articles per country in column "number_of_articles"
regional = wp_politicians_by_country.groupby('region').count()['name'].reset_index().rename({"name":"number_of_articles"}, axis=1)
#We merge with population table to obtain the population data for each region
total_articles_per_population_region = regional.merge(population[['Geography','Population (millions)']], how='left', left_on= 'region', right_on = 'Geography')
#We create a new column with the total_articles_per_population which is the division of number of articles by population. 
total_articles_per_population_region['total_articles_per_population'] = total_articles_per_population_region['number_of_articles']/total_articles_per_population_region['Population (millions)']
total_articles_per_population_region
# Out:
#              region  number_of_articles        Geography  \
# 0         CARIBBEAN                 201        CARIBBEAN
# 1   CENTRAL AMERICA                 195  CENTRAL AMERICA
# 2      CENTRAL ASIA                 106     CENTRAL ASIA
# 3         EAST ASIA                 245        EAST ASIA
# 4    EASTERN AFRICA                 648   EASTERN AFRICA
# 5    EASTERN EUROPE                 736   EASTERN EUROPE
# 6     MIDDLE AFRICA                 203    MIDDLE AFRICA
# 7   NORTHERN AFRICA                 227  NORTHERN AFRICA
# 8   NORTHERN EUROPE                 262  NORTHERN EUROPE
# 9           OCEANIA                  72          OCEANIA
# 10    SOUTH AMERICA                 577    SOUTH AMERICA
# 11       SOUTH ASIA                 648       SOUTH ASIA
# 12   SOUTHEAST ASIA                 412   SOUTHEAST ASIA
# 13  SOUTHERN AFRICA                 117  SOUTHERN AFRICA
# 14  SOUTHERN EUROPE                 888  SOUTHERN EUROPE
# 15   WESTERN AFRICA                 568   WESTERN AFRICA
# 16     WESTERN ASIA                 686     WESTERN ASIA
# 17   WESTERN EUROPE                 684   WESTERN EUROPE
#
#     Population (millions)  total_articles_per_population
# 0                    44.0                       4.568182
# 1                   178.0                       1.095506
# 2                    78.0                       1.358974
# 3                  1674.0                       0.146356
# 4                   473.0                       1.369979
# 5                   287.0                       2.564460
# 6                   196.0                       1.035714
# 7                   251.0                       0.904382
# 8                   107.0                       2.448598
# 9                    44.0                       1.636364
# 10                  434.0                       1.329493
# 11                 2008.0                       0.322709
# 12                  676.0                       0.609467
# 13                   69.0                       1.695652
# 14                  151.0                       5.880795
# 15                  430.0                       1.320930
# 16                  294.0                       2.333333
# 17                  197.0                       3.472081

# %% [markdown]
#  ## high-quality-articles-per-population (a ratio representing the number of high quality articles per person)

# %%
#Country-by-country
#We groupby country, summing the number of articles that are classified as high quality per country in column "number_of_high_quality"
count_by_country_hq = wp_politicians_by_country.groupby('country').sum()['high_quality'].reset_index().rename({"high_quality":"number_of_high_quality"}, axis=1)
#We merge with population table to obtain the population data for each country
hq_articles_per_population_country = count_by_country_hq.merge(population, how='left', left_on= 'country', right_on = 'Geography')
#We create a new column with the hq_articles_per_population which is the division of number of high quality articles by population. 
hq_articles_per_population_country['hq_articles_per_population'] = hq_articles_per_population_country["number_of_high_quality"]/total_articles_per_population_country['Population (millions)']
hq_articles_per_population_country
# Out:
#          country  number_of_high_quality    Geography  Population (millions)  \
# 0    Afghanistan                       6  Afghanistan                   41.1
# 1        Albania                       6      Albania                    2.8
# 2        Algeria                       0      Algeria                   44.9
# 3        Andorra                       2      Andorra                    0.1
# 4         Angola                       0       Angola                   35.6
# ..           ...                     ...          ...                    ...
# 173    Venezuela                       0    Venezuela                   28.3
# 174      Vietnam                       2      Vietnam                   99.4
# 175        Yemen                       2        Yemen                   33.7
# 176       Zambia                       0       Zambia                   20.0
# 177     Zimbabwe                       0     Zimbabwe                   16.3
#
#               region  hq_articles_per_population
# 0         SOUTH ASIA                    0.145985
# 1    SOUTHERN EUROPE                    2.142857
# 2    NORTHERN AFRICA                    0.000000
# 3    SOUTHERN EUROPE                   20.000000
# 4      MIDDLE AFRICA                    0.000000
# ..               ...                         ...
# 173    SOUTH AMERICA                    0.000000
# 174   SOUTHEAST ASIA                    0.020121
# 175     WESTERN ASIA                    0.059347
# 176   EASTERN AFRICA                    0.000000
# 177   EASTERN AFRICA                    0.000000
#
# [178 rows x 6 columns]

# %%
#Regional
#We groupby region, summing the number of articles that are classified as high quality per country in column "number_of_high_quality"
regional_hq = wp_politicians_by_country.groupby('region').sum()['high_quality'].reset_index().rename({"high_quality":"number_of_high_quality"}, axis=1)
#We merge with population table to obtain the population data for each region
hq_articles_per_population_region = regional_hq.merge(population[['Geography','Population (millions)']], how='left', left_on= 'region', right_on = 'Geography')
#We create a new column with the hq_articles_per_population which is the division of number of high quality articles by population. 
hq_articles_per_population_region['hq_articles_per_population'] = hq_articles_per_population_region['number_of_high_quality']/hq_articles_per_population_region['Population (millions)']
hq_articles_per_population_region
# Out:
#              region  number_of_high_quality        Geography  \
# 0         CARIBBEAN                       8        CARIBBEAN
# 1   CENTRAL AMERICA                      10  CENTRAL AMERICA
# 2      CENTRAL ASIA                       3     CENTRAL ASIA
# 3         EAST ASIA                      16        EAST ASIA
# 4    EASTERN AFRICA                      15   EASTERN AFRICA
# 5    EASTERN EUROPE                      39   EASTERN EUROPE
# 6     MIDDLE AFRICA                       5    MIDDLE AFRICA
# 7   NORTHERN AFRICA                       6  NORTHERN AFRICA
# 8   NORTHERN EUROPE                       8  NORTHERN EUROPE
# 9           OCEANIA                       1          OCEANIA
# 10    SOUTH AMERICA                      13    SOUTH AMERICA
# 11       SOUTH ASIA                      23       SOUTH ASIA
# 12   SOUTHEAST ASIA                      24   SOUTHEAST ASIA
# 13  SOUTHERN AFRICA                       4  SOUTHERN AFRICA
# 14  SOUTHERN EUROPE                      46  SOUTHERN EUROPE
# 15   WESTERN AFRICA                      13   WESTERN AFRICA
# 16     WESTERN ASIA                      28     WESTERN ASIA
# 17   WESTERN EUROPE                      22   WESTERN EUROPE
#
#     Population (millions)  hq_articles_per_population
# 0                    44.0                    0.181818
# 1                   178.0                    0.056180
# 2                    78.0                    0.038462
# 3                  1674.0                    0.009558
# 4                   473.0                    0.031712
# 5                   287.0                    0.135889
# 6                   196.0                    0.025510
# 7                   251.0                    0.023904
# 8                   107.0                    0.074766
# 9                    44.0                    0.022727
# 10                  434.0                    0.029954
# 11                 2008.0                    0.011454
# 12                  676.0                    0.035503
# 13                   69.0                    0.057971
# 14                  151.0                    0.304636
# 15                  430.0                    0.030233
# 16                  294.0                    0.095238
# 17                  197.0                    0.111675

# %% [markdown]
# ### 1. Top 10 countries by coverage: The 10 countries with the highest total articles per capita (in descending order).

# %%
total_articles_per_population_country.sort_values(by=['total_articles_per_population'], ascending=False)[:10]
# Out:
#                             country  number_of_articles  \
# 5               Antigua and Barbuda                  17
# 54   Federated States of Micronesia                  13
# 3                           Andorra                  10
# 13                         Barbados                  28
# 103                Marshall Islands                   9
# 108                      Montenegro                  36
# 138                      Seychelles                   6
# 96                       Luxembourg                  37
# 18                           Bhutan                  41
# 64                          Grenada                   5
#
#                           Geography  Population (millions)           region  \
# 5               Antigua and Barbuda                    0.1        CARIBBEAN
# 54   Federated States of Micronesia                    0.1          OCEANIA
# 3                           Andorra                    0.1  SOUTHERN EUROPE
# 13                         Barbados                    0.3        CARIBBEAN
# 103                Marshall Islands                    0.1          OCEANIA
# 108                      Montenegro                    0.6  SOUTHERN EUROPE
# 138                      Seychelles                    0.1   EASTERN AFRICA
# 96                       Luxembourg                    0.7   WESTERN EUROPE
# 18                           Bhutan                    0.8       SOUTH ASIA
# 64                          Grenada                    0.1        CARIBBEAN
#
#      total_articles_per_population
# 5                       170.000000
# 54                      130.000000
# 3                       100.000000
# 13                       93.333333
# 103                      90.000000
# 108                      60.000000
# 138                      60.000000
# 96                       52.857143
# 18                       51.250000
# 64                       50.000000

# %% [markdown]
# ### 2. Bottom 10 countries by coverage: The 10 countries with the lowest total articles per capita (in ascending order).

# %%
total_articles_per_population_country.sort_values(by=['total_articles_per_population'])[:10]
# Out:
#           country  number_of_articles     Geography  Population (millions)  \
# 32          China                   2         China                 1436.6
# 105        Mexico                   1        Mexico                  127.5
# 135  Saudi Arabia                   3  Saudi Arabia                   36.7
# 130       Romania                   2       Romania                   19.0
# 73          India                 178         India                 1417.2
# 148     Sri Lanka                   3     Sri Lanka                   22.4
# 48          Egypt                  14         Egypt                  103.5
# 53       Ethiopia                  25      Ethiopia                  123.4
# 156        Taiwan                   5        Taiwan                   23.2
# 174       Vietnam                  27       Vietnam                   99.4
#
#               region  total_articles_per_population
# 32         EAST ASIA                       0.001392
# 105  CENTRAL AMERICA                       0.007843
# 135     WESTERN ASIA                       0.081744
# 130   EASTERN EUROPE                       0.105263
# 73        SOUTH ASIA                       0.125600
# 148       SOUTH ASIA                       0.133929
# 48   NORTHERN AFRICA                       0.135266
# 53    EASTERN AFRICA                       0.202593
# 156        EAST ASIA                       0.215517
# 174   SOUTHEAST ASIA                       0.271630

# %% [markdown]
# ### 3.Top 10 countries by high quality: The 10 countries with the highest high quality articles per capita (in descending order) .

# %%
hq_articles_per_population_country.sort_values(by=['hq_articles_per_population'], ascending=False)[:10]
# Out:
#                    country  number_of_high_quality              Geography  \
# 3                  Andorra                       2                Andorra
# 108             Montenegro                       3             Montenegro
# 1                  Albania                       6                Albania
# 152               Suriname                       1               Suriname
# 20      Bosnia-Herzegovina                       5     Bosnia-Herzegovina
# 95               Lithuania                       3              Lithuania
# 39                 Croatia                       4                Croatia
# 142               Slovenia                       2               Slovenia
# 122  Palestinian Territory                       5  Palestinian Territory
# 58                   Gabon                       2                  Gabon
#
#      Population (millions)           region  hq_articles_per_population
# 3                      0.1  SOUTHERN EUROPE                   20.000000
# 108                    0.6  SOUTHERN EUROPE                    5.000000
# 1                      2.8  SOUTHERN EUROPE                    2.142857
# 152                    0.6    SOUTH AMERICA                    1.666667
# 20                     3.4  SOUTHERN EUROPE                    1.470588
# 95                     2.8  NORTHERN EUROPE                    1.071429
# 39                     3.8  SOUTHERN EUROPE                    1.052632
# 142                    2.1  SOUTHERN EUROPE                    0.952381
# 122                    5.4     WESTERN ASIA                    0.925926
# 58                     2.4    MIDDLE AFRICA                    0.833333

# %% [markdown]
# ### 4. Bottom 10 countries by high quality: The 10 countries with the lowest high quality articles per capita (in ascending order).

# %%
hq_articles_per_population_country.sort_values(by=['hq_articles_per_population'])[:10]
# Out:
#                             country  number_of_high_quality  \
# 177                        Zimbabwe                       0
# 176                          Zambia                       0
# 87                           Kuwait                       0
# 148                       Sri Lanka                       0
# 149                 St. Kitts-Nevis                       0
# 79                          Jamaica                       0
# 78                            Italy                       0
# 77                           Israel                       0
# 72                          Iceland                       0
# 150  St. Vincent and the Grenadines                       0
#
#                           Geography  Population (millions)           region  \
# 177                        Zimbabwe                   16.3   EASTERN AFRICA
# 176                          Zambia                   20.0   EASTERN AFRICA
# 87                           Kuwait                    4.1     WESTERN ASIA
# 148                       Sri Lanka                   22.4       SOUTH ASIA
# 149                 St. Kitts-Nevis                    0.1        CARIBBEAN
# 79                          Jamaica                    2.8        CARIBBEAN
# 78                            Italy                   58.9  SOUTHERN EUROPE
# 77                           Israel                    9.5     WESTERN ASIA
# 72                          Iceland                    0.4  NORTHERN EUROPE
# 150  St. Vincent and the Grenadines                    0.1        CARIBBEAN
#
#      hq_articles_per_population
# 177                         0.0
# 176                         0.0
# 87                          0.0
# 148                         0.0
# 149                         0.0
# 79                          0.0
# 78                          0.0
# 77                          0.0
# 72                          0.0
# 150                         0.0

# %% [markdown]
# ### 5. Geographic regions by total coverage: A rank ordered list of geographic regions (in descending order) by total articles per capita.

# %%
total_articles_per_population_region.sort_values(by=['total_articles_per_population'], ascending=False)[:10]
# Out:
#              region  number_of_articles        Geography  \
# 14  SOUTHERN EUROPE                 888  SOUTHERN EUROPE
# 0         CARIBBEAN                 201        CARIBBEAN
# 17   WESTERN EUROPE                 684   WESTERN EUROPE
# 5    EASTERN EUROPE                 736   EASTERN EUROPE
# 8   NORTHERN EUROPE                 262  NORTHERN EUROPE
# 16     WESTERN ASIA                 686     WESTERN ASIA
# 13  SOUTHERN AFRICA                 117  SOUTHERN AFRICA
# 9           OCEANIA                  72          OCEANIA
# 4    EASTERN AFRICA                 648   EASTERN AFRICA
# 2      CENTRAL ASIA                 106     CENTRAL ASIA
#
#     Population (millions)  total_articles_per_population
# 14                  151.0                       5.880795
# 0                    44.0                       4.568182
# 17                  197.0                       3.472081
# 5                   287.0                       2.564460
# 8                   107.0                       2.448598
# 16                  294.0                       2.333333
# 13                   69.0                       1.695652
# 9                    44.0                       1.636364
# 4                   473.0                       1.369979
# 2                    78.0                       1.358974

# %% [markdown]
# ### 6. Geographic regions by high quality coverage: Rank ordered list of geographic regions (in descending order) by high quality articles per capita.

# %%
hq_articles_per_population_region.sort_values(by=['hq_articles_per_population'], ascending=False)[:10]
# Out:
#              region  number_of_high_quality        Geography  \
# 14  SOUTHERN EUROPE                      46  SOUTHERN EUROPE
# 0         CARIBBEAN                       8        CARIBBEAN
# 5    EASTERN EUROPE                      39   EASTERN EUROPE
# 17   WESTERN EUROPE                      22   WESTERN EUROPE
# 16     WESTERN ASIA                      28     WESTERN ASIA
# 8   NORTHERN EUROPE                       8  NORTHERN EUROPE
# 13  SOUTHERN AFRICA                       4  SOUTHERN AFRICA
# 1   CENTRAL AMERICA                      10  CENTRAL AMERICA
# 2      CENTRAL ASIA                       3     CENTRAL ASIA
# 12   SOUTHEAST ASIA                      24   SOUTHEAST ASIA
#
#     Population (millions)  hq_articles_per_population
# 14                  151.0                    0.304636
# 0                    44.0                    0.181818
# 5                   287.0                    0.135889
# 17                  197.0                    0.111675
# 16                  294.0                    0.095238
# 8                   107.0                    0.074766
# 13                   69.0                    0.057971
# 1                   178.0                    0.056180
# 2                    78.0                    0.038462
# 12                  676.0                    0.035503
